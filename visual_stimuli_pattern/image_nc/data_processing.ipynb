# %%
import numpy as np
import pickle

# %%
with open("/media/ubuntu/sda/visual_stimuli_pattern/image_nc/cadena_ploscb_data.pkl", 'rb') as f:
    a = pickle.load(f)

# %%
a.keys()
# Out:
# dict_keys(['repetitions', 'subject_id', 'session_id', 'image_ids', 'unit_id', 'image_types', 'images', 'responses', 'image_numbers'])

# %%
a['responses'].shape
# Out:
# (4, 7250, 166)

# %%
b = a['image_types']

# %%
np.where(b == ['original'])[0]
# Out:
# array([   0,    5,   10, ..., 7235, 7240, 7245], shape=(1450,))

# %%
import matplotlib.pyplot as plt

plt.imshow(a['images'][30, :, :], cmap='gray')
