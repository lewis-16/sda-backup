# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
from tqdm import tqdm
import os
import gc
import pickle

# %%
# 读取数据
clustering_results = pd.read_csv("clustering_results.csv")
tsne_features = pd.read_csv("tsne_features.csv")
pca_features = pd.read_csv("pca_features.csv")

# %%
clustering_results
# Out:
#        sample_id  kmeans_cluster  dbscan_cluster  hierarchical_cluster  \
# 0              0               1              -1                     4
# 1              1               2              -1                     1
# 2              2               0              -1                     3
# 3              3               2              -1                     3
# 4              4               2              -1                     1
# ...          ...             ...             ...                   ...
# 22243      22243               0              -1                     3
# 22244      22244               2              -1                     1
# 22245      22245               2              -1                     1
# 22246      22246               0             863                     0
# 22247      22247               2              32                     1
#
#        true_label class_name
# 0               0   aardvark
# 1               0   aardvark
# 2               0   aardvark
# 3               0   aardvark
# 4               0   aardvark
# ...           ...        ...
# 22243        1853   zucchini
# 22244        1853   zucchini
# 22245        1853   zucchini
# 22246        1853   zucchini
# 22247        1853   zucchini
#
# [22248 rows x 6 columns]
