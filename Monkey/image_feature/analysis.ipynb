# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
monkeyF_feature = pd.read_csv("/Users/jin/Downloads/image_feature/neuron_preferred_axes_results.csv")

# %%
sns.scatterplot(x = monkeyF_feature['pc1_projection'],
                y = monkeyF_feature['pc2_projection'],
                hue = monkeyF_feature['neuron_id'],
                palette = 'viridis',
                s = 5,
                alpha = 0.7)
plt.xlabel('PC1 Projection')
plt.ylabel('PC2 Projection')
# Out:
# Text(0, 0.5, 'PC2 Projection')

# %%
# Out:
# <Axes: xlabel='prediction_correlation', ylabel='Count'>

# %%
# Out:
# <Axes: xlabel='prediction_correlation', ylabel='Count'>

# %%
sns.histplot(monkeyF_feature['prediction_correlation'][:271])
sns.histplot(monkeyF_feature['prediction_correlation'][271:271+125])
sns.histplot(monkeyF_feature['prediction_correlation'][271+125:])
# Out:
# <Axes: xlabel='prediction_correlation', ylabel='Count'>

# %%
sns.histplot(monkeyF_feature['prediction_correlation'][400:])
# Out:
# <Axes: xlabel='prediction_correlation', ylabel='Count'>
