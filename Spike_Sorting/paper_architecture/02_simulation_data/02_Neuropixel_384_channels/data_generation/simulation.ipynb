# %% [markdown]
# ## Generate Templates

# %%
import MEArec as mr
import numpy as np
import matplotlib.pylab as plt
from pprint import pprint
# %matplotlib inline

# %%
templates_params = mr.get_default_templates_params()
cell_models_folder = mr.get_default_cell_models_folder()

# %%
templates_params['max_drift'] = 0
templates_params['min_drift'] = 0

# %%
templates_params['probe'] = 'Neuropixels-384'
templates_params['n'] = 10

# %%
tempgen = mr.gen_templates
tempgen = mr.gen_templates(cell_models_folder=cell_models_folder, params=templates_params, verbose=True)
# Out:
# Setting n_jobs to 32 CPUs
# Running with 32 jobs
# Starting simulation 2/13 - cell: L5_BTC_bAC217_1
#
# Starting simulation 1/13 - cell: L5_BP_bAC217_1
#
# Starting simulation 9/13 - cell: L5_SBC_bNAC219_1
#
# Starting simulation 10/13 - cell: L5_STPC_cADpyr232_1
#
# Starting simulation 12/13 - cell: L5_TTPC2_cADpyr232_1
#
# Starting simulation 7/13 - cell: L5_NBC_bAC217_1
#
# Starting simulation 6/13 - cell: L5_MC_bAC217_1
#
# Starting simulation 3/13 - cell: L5_ChC_cACint209_1
#
# Starting simulation 5/13 - cell: L5_LBC_bAC217_1
#
# Starting simulation 8/13 - cell: L5_NGC_bNAC219_1
#
# Starting simulation 4/13 - cell: L5_DBC_bAC217_1
#
# Starting simulation 11/13 - cell: L5_TTPC1_cADpyr232_1
#
# Starting simulation 13/13 - cell: L5_UTPC_cADpyr232_1
#
# Intracellular simulation: /home/ubuntu/.config/mearec/1.9.2/cell_models/bbp/L5_BP_bAC217_1
# Intracellular simulation: /home/ubuntu/.config/mearec/1.9.2/cell_models/bbp/L5_BTC_bAC217_1
#
#
#
# ...

# %%
templates_filename = '/media/ubuntu/sda/Spike_Sorting/paper_architecture/02_simulation_data/02_Neuropixel_384_channels/data_generation/templates_300_neuropixels_type1.h5'
mr.save_template_generator(tempgen, filename=f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/02_simulation_data/02_Neuropixel_384_channels/data_generation/templates_300_neuropixels_type1.h5')

tempgen = mr.load_templates(templates_filename)
# Out:
# Saved  templates in /media/ubuntu/sda/Spike_Sorting/paper_architecture/02_simulation_data/02_Neuropixel_384_channels/data_generation/templates_300_neuropixels_type1.h5

# %%
recording_params = mr.get_default_recordings_params()
recording_params['spiketrains']['n_exc'] = 5
recording_params['spiketrains']['n_inh'] = 5
recording_params['spiketrains']['duration'] = 20
recording_params['spiketrains']['seed'] = 1


recording_params['templates']['min_amp'] = 40
recording_params['templates']['max_amp'] = 300
recording_params['templates']['seed'] = 1

recording_params['recordings']['modulation'] = 'electrode'
recording_params['recordings']['noise_mode'] = 'uncorrelated'
recording_params['recordings']['noise_level'] = 10
# use chunk options
recording_params['recordings']['chunk_conv_duration'] = 20
recording_params['recordings']['chunk_noise_duration'] = 20
recording_params['recordings']['chunk_filter_duration'] = 20
recording_params['recordings']['seed'] = 1
recording_params['recordings']['fs'] = 10000

# %%
recgen = mr.gen_recordings(templates=templates_filename, params=recording_params, verbose=True)
# Out:
# Loading templates...
# Done loading templates...
# Spiketrains seed:  4478
# dtype float32
# Noise Level  10
# Templates selection seed:  300
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.7467942237854004
# Resampling templates at 10000.0 Hz
# Elapsed resample time: 0.044066429138183594
# Creating time jittering
# Elapsed jitter time: 0.2395458221435547
# Smoothing templates
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  8075
# Electrode modulaton
# Adding noise
# Noise seed:  7500
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  14.327497919999587

# %%
mr.save_recording_generator(recgen, '/media/ubuntu/sda/Spike_Sorting/paper_architecture/02_simulation_data/02_Neuropixel_384_channels/data_generation/recording_neuropixels_type1.h5')
