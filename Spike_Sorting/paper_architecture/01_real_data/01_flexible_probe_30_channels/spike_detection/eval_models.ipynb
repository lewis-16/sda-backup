# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import spikeinterface as si
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages

from tqdm import tqdm


import sys
import spikeinterface as si
import matplotlib.pyplot as plt
import spikeinterface.extractors as se
import spikeinterface.preprocessing as spre
import spikeinterface.sorters as ss
import spikeinterface.widgets as sw
import spikeinterface.qualitymetrics as sqm
import json
import probeinterface

from probeinterface import Probe, ProbeGroup
from probeinterface.plotting import plot_probe, plot_probegroup
from probeinterface import generate_dummy_probe, generate_linear_probe
from probeinterface import write_probeinterface, read_probeinterface
from probeinterface import write_prb, read_prb
from torch.nn.functional import max_pool1d


import torch.nn.functional as F
from pathlib import Path


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torch.utils.data import Subset
from scipy.signal import find_peaks

# from function.Function import *

# %%
def count_array2_in_range_of_array1(array1, array2, threshold=5):

    sorted_array1 = np.sort(array1)
    
    lefts = array2 - threshold
    rights = array2 + threshold
    
    left_indices = np.searchsorted(sorted_array1, lefts, side='left')
    
    right_indices = np.searchsorted(sorted_array1, rights, side='right')
    
    has_within_range = right_indices > left_indices
    
    count = np.sum(has_within_range)
    
    return count


def detect_local_minimum_in_window(data, window_size=20, std_multiplier=2, overlap_ratio=1/3):

    """
    使用scipy.signal.find_peaks在每个滑动窗口范围内检测峰值索引。
    对数据取绝对值以检测正负spike，然后在每个窗口内只保留最大值索引。

    参数:
    data : numpy.ndarray
        输入数据，形状为 (n_rows, n_columns)。
    window_size : int
        滑动窗口的大小，用于定义局部范围，默认为 20。
    std_multiplier : float
        标准差的倍数，用于筛选峰值，默认为 2。
    overlap_ratio : float
        窗口重叠比例，默认为 1/3（即步长 = window_size * (1 - overlap_ratio)）。

    返回:
    local_minima_indices : list
        所有通道峰值索引列表（已去重）。
    """
    # 计算步长（窗口重叠）
    step_size = int(window_size * (1 - overlap_ratio))
    
    local_minima_indices = []

    # 优化：批量处理所有通道，减少循环开销
    data = np.asarray(data, dtype=np.float32)
    n_channels, n_samples = data.shape
    
    # 优化：预计算窗口边界（所有通道共享）
    window_starts = np.arange(0, n_samples, step_size)
    window_ends = np.minimum(window_starts + window_size, n_samples)
    
    for channel_idx in range(n_channels):
        row = data[channel_idx]
        # 对数据取绝对值以检测正负spike
        abs_row = np.abs(row)
        # 优化：使用更快的统计计算
        abs_mean = abs_row.mean()
        abs_std = abs_row.std()
        # 阈值：绝对值高于 mean + std_multiplier * std 的峰值
        abs_threshold = abs_mean + std_multiplier * abs_std
        
        # 使用find_peaks检测绝对值信号中的峰值（每个通道只调用一次）
        peaks, _ = find_peaks(
            abs_row,
            height=abs_threshold,  # 峰值必须高于此值
            distance=window_size // 2  # 峰值之间的最小距离
        )
        
        if len(peaks) == 0:
            continue
        
        # 在每个滑动窗口内只保留一个峰值（最大值）
        windowed_peaks = []
        
        # 优化：使用向量化操作快速找到窗口内的峰值
        for start, end in zip(window_starts, window_ends):
            # 找到在当前窗口内的所有峰值（向量化操作）
            window_peaks = peaks[(peaks >= start) & (peaks < end)]
            
            if len(window_peaks) == 0:
                continue
            
            # 如果窗口内有多个峰值，选择绝对值最大的
            if len(window_peaks) > 1:
                abs_peak_values = abs_row[window_peaks]
                max_abs_idx = np.argmax(abs_peak_values)
                selected_peak = window_peaks[max_abs_idx]
            else:
                selected_peak = window_peaks[0]
            
            # 验证是否满足阈值条件（已经在find_peaks中验证，但保留作为安全检查）
            if abs_row[selected_peak] >= abs_threshold:
                windowed_peaks.append(int(selected_peak))
        
        local_minima_indices.extend(windowed_peaks)
    
    # 去重并排序
    local_minima_indices = sorted(list(set(local_minima_indices)))

    return local_minima_indices


def cluster_label_array1_based_on_array2(array1, array2, threshold=5):

    """
    根据 array2 的 'time' 和 'cluster' 对 array1 进行标记。
    如果 array1 中的某个值在 threshold 范围内存在于 array2 的 'time' 中，则标记为对应的 'cluster' 值，否则为 0。
    
    参数:
    array1 : numpy.ndarray
        要标记的数组。
    array2 : numpy.ndarray
        包含 'time' 和 'cluster' 的二维数组。
        第一列为 'time'，第二列为 'cluster'。
    threshold : int
        判断范围的阈值。
    
    返回:
    labels : numpy.ndarray
        长度为 len(array1) 的标签数组，值为 array2 中的 'cluster' 或 0。
    """

    array2 = np.array(array2.iloc[:, [5, 1]])
    sorted_indices = np.argsort(array2[:, 0])
    sorted_array2 = array2[sorted_indices]
    
    labels = np.zeros(len(array1), dtype=int)
    
    # 遍历 array1 中的每个元素
    for i, value in enumerate(array1):
        # 计算当前值的范围
        left = value - threshold
        right = value + threshold
        
        left_index = np.searchsorted(sorted_array2[:, 0], left, side='left')
        right_index = np.searchsorted(sorted_array2[:, 0], right, side='right')
        
        # 如果范围内存在值，则标记为对应的 'cluster'
        if right_index > left_index:
            # 获取范围内的第一个匹配值的 'cluster'
            labels[i] = sorted_array2[left_index, 1]
    
    return labels


def label_array1_based_on_array2(array1, array2, threshold=5):

    """
    根据 array2 的值对 array1 进行标记（一对一匹配）。
    使用最近邻匹配策略，确保每个GT spike最多只匹配一个检测到的spike。
    如果 array1 中的某个值在 threshold 范围内有匹配的 array2 值，则标记为 1，否则为 0。
    
    参数:
    array1 : numpy.ndarray
        要标记的数组（检测到的spike时间点）。
    array2 : numpy.ndarray
        用于判断的数组（ground truth spike时间点）。
    threshold : int
        判断范围的阈值。
    
    返回:
    labels : numpy.ndarray
        长度为 len(array1) 的标签数组，值为 0 或 1。
    """
    array1 = np.array(array1)
    array2 = np.array(array2)
    
    # 初始化标签数组，默认值为 0
    labels = np.zeros(len(array1), dtype=int)
    
    if len(array2) == 0:
        return labels
    
    # 使用最近邻匹配策略：确保每个ground truth spike最多只匹配一个检测spike
    # 对 array2 进行排序以加速搜索
    sorted_array2 = np.sort(array2)
    
    # 记录每个ground truth spike是否已被匹配
    matched_gt_indices = set()
    
    # 对 array1 按值排序，以便优先匹配更接近的spike
    sorted_indices = np.argsort(array1)
    
    # 对于每个检测到的spike，找到最近的ground truth spike
    for idx in sorted_indices:
        value = array1[idx]
        
        # 找到最近的ground truth spike
        nearest_idx = np.searchsorted(sorted_array2, value, side='left')
        
        # 检查左右两个候选位置
        candidates = []
        if nearest_idx > 0:
            candidates.append((nearest_idx - 1, sorted_array2[nearest_idx - 1]))
        if nearest_idx < len(sorted_array2):
            candidates.append((nearest_idx, sorted_array2[nearest_idx]))
        
        # 找到距离最近的候选
        if candidates:
            best_idx, best_value = min(candidates, key=lambda x: abs(x[1] - value))
            distance = abs(best_value - value)
            
            # 如果距离在阈值内且该ground truth spike未被匹配
            if distance <= threshold and best_idx not in matched_gt_indices:
                labels[idx] = 1
                matched_gt_indices.add(best_idx)
    
    return labels


def extract_windows(data, indices, window_size=61):
    """
    根据给定的时间点索引提取窗口。
    
    参数:
    data : numpy.ndarray
        输入数据，形状为 (n_channels, time)
    indices : numpy.ndarray
        时间点索引数组，用于指定需要提取窗口的中心点
    window_size : int
        窗口长度，默认为61（对应time-30到time+31）
    
    返回:
    windows : numpy.ndarray
        提取的窗口数据，形状为 (len(indices), n_channels, window_size)
    """
    n_channels, time_length = data.shape
    half_window = window_size // 2

    if np.any(indices < half_window) or np.any(indices >= time_length - half_window):
        raise ValueError("Some indices are out of bounds for the given window size.")

    windows = []
    for idx in indices:
        window = data[:, idx - half_window:idx + half_window + 1]
        windows.append(window)

    windows = np.array(windows)
    return windows


def label_gt_spikes_with_detections(gt_times, detected_times, threshold=5):
    """
    标记ground truth spike是否被检测到。
    使用最近邻匹配策略，确保与label_array1_based_on_array2的匹配逻辑一致。
    如果某个ground truth spike在threshold范围内有检测到的spike匹配，则标记为1，否则为0。
    
    参数:
    gt_times : numpy.ndarray
        Ground truth spike时间点数组。
    detected_times : numpy.ndarray
        检测到的spike时间点数组。
    threshold : int
        判断范围的阈值（采样点数）。
    
    返回:
    match_labels : numpy.ndarray
        长度为 len(gt_times) 的标签数组，值为 0 或 1。
    """
    gt_times = np.array(gt_times)
    detected_times = np.array(detected_times)
    
    # 初始化标签数组，默认值为 0
    match_labels = np.zeros(len(gt_times), dtype=int)
    
    if len(detected_times) == 0:
        return match_labels
    
    # 使用与label_array1_based_on_array2相同的最近邻匹配策略
    # 对ground truth和检测到的spike进行排序
    sorted_gt = np.sort(gt_times)
    sorted_detected = np.sort(detected_times)
    
    # 记录每个ground truth spike是否已被匹配
    matched_gt_indices = set()
    
    # 对检测到的spike按值排序，以便优先匹配更接近的spike
    sorted_detected_indices = np.argsort(detected_times)
    
    # 对于每个检测到的spike，找到最近的ground truth spike
    for det_idx in sorted_detected_indices:
        det_time = detected_times[det_idx]
        
        # 找到最近的ground truth spike
        nearest_idx = np.searchsorted(sorted_gt, det_time, side='left')
        
        # 检查左右两个候选位置
        candidates = []
        if nearest_idx > 0:
            candidates.append((nearest_idx - 1, sorted_gt[nearest_idx - 1]))
        if nearest_idx < len(sorted_gt):
            candidates.append((nearest_idx, sorted_gt[nearest_idx]))
        
        # 找到距离最近的候选
        if candidates:
            best_gt_idx_in_sorted, best_gt_time = min(candidates, key=lambda x: abs(x[1] - det_time))
            distance = abs(best_gt_time - det_time)
            
            # 如果距离在阈值内且该ground truth spike未被匹配
            if distance <= threshold and best_gt_idx_in_sorted not in matched_gt_indices:
                matched_gt_indices.add(best_gt_idx_in_sorted)
    
    # 将匹配结果映射回原始ground truth索引
    # 需要找到sorted_gt中每个索引对应的原始索引
    gt_sorted_indices = np.argsort(gt_times)
    for sorted_idx in matched_gt_indices:
        original_idx = gt_sorted_indices[sorted_idx]
        match_labels[original_idx] = 1
    
    return match_labels

# %%
class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx].astype(np.float32), self.labels[idx]
    
class Spike_Detection_MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size, n_channels, time_window):
        super(Spike_Detection_MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, 16)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(16, output_size)
        self.sigmoid = nn.Sigmoid()  

        self.n_channels = n_channels
        self.time_window = time_window
    def forward(self, x):
        x = x.reshape(-1, self.n_channels * self.time_window)
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.sigmoid(x)
        return x

# %%
# eval_date_list = ['022522', '031722', '042422', '052422', '062422',
#                   '072322', '082322', '092422', '102122', '112022', '122022']
eval_date_list = ['022522', '031722']

# %%
tpr_dict = {}
tnr_dict = {}
accuracy_dict = {}

for date in eval_date_list:
    tpr_dict[date] = []
    tnr_dict[date] = []
    accuracy_dict[date] = []
    print(f"Processing date: {date}")

    recording_raw = se.read_blackrock(file_path=f'/media/ubuntu/sda/data/mouse6/ns4/natural_image/mouse6_{date}_natural_image_001.ns4')
    recording_recorded = recording_raw.remove_channels(["98", '31', '32'])

    recording_f = spre.bandpass_filter(recording_recorded, freq_min=300, freq_max=3000)
    recording_f = spre.common_reference(recording_f, reference="global", operator="median")
    spike_inf = pd.read_csv(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_new/{date}/spike_inf.tsv", sep = '\t', index_col = 0)


    total_frames = int(recording_f.get_total_duration() * 10000)
    chunk_size = 300000  
    window_size = 31
    half_window = window_size // 2
    
    print(f"[INFO] Total frames: {total_frames:,} | Chunk size: {chunk_size:,} | Window size: {window_size}")
    
    input_size = 30 * 31
    hidden_size1 = 128
    hidden_size2 = 32
    output_size = 1  
    device = 'cuda'
    
    all_valid_indices = []
    all_windows = []
    
    # 计算总chunk数用于进度条
    total_chunks = (total_frames + chunk_size - 1) // chunk_size
    print(f"[INFO] Processing {total_chunks} chunks...")
    
    for start_frame in tqdm(range(0, total_frames, chunk_size), 
                             desc="Detecting spikes", 
                             unit="chunk",
                             total=total_chunks):
        end_frame = min(start_frame + chunk_size, total_frames)
        
        data_chunk = recording_f.get_traces(
            start_frame=start_frame,
            end_frame=end_frame
        )  # shape: (n_channels, chunk_size)
        
        threshold_result = detect_local_minimum_in_window(
            data_chunk.T,
            std_multiplier=2.5,
            window_size=15,
            overlap_ratio=1/3
        )
        
        threshold_result = np.array(threshold_result) + start_frame
        valid_indices = threshold_result[
            (threshold_result >= start_frame + half_window + 1) &
            (threshold_result < end_frame - half_window)
        ]
        
        for idx in valid_indices:
            rel_idx = idx - start_frame
            window = data_chunk.T[:, rel_idx - half_window: rel_idx + half_window + 1]
            all_windows.append(window)
        
        all_valid_indices.extend(valid_indices)

    all_valid_indices = np.array(all_valid_indices)
    all_windows = np.stack(all_windows)
    original_count = len(all_valid_indices)
    print(f"[INFO] Extracted {original_count:,} candidate spikes before deduplication")
    
    # 按时间点去重：同一时间点只保留一个检测
    print("[INFO] Deduplicating by time point...")
    unique_indices, unique_positions = np.unique(all_valid_indices, return_index=True)
    all_valid_indices = unique_indices
    all_windows = all_windows[unique_positions]
    deduplicated_count = len(all_valid_indices)
    print(f"[INFO] After deduplication: {deduplicated_count:,} spikes (removed {original_count - deduplicated_count:,} duplicates)")

    labels = label_array1_based_on_array2(all_valid_indices, spike_inf['time'], threshold=2)
    labels = np.array(labels)
    detected_spike_count = len(all_valid_indices)
    matched_spike_count = int(np.sum(labels == 1))
    total_gt_spikes = len(spike_inf)
    coverage = matched_spike_count / total_gt_spikes if total_gt_spikes > 0 else 0
    print(f"[INFO] Spike detection summary:")
    print(f"       - Detected spikes: {detected_spike_count:,}")
    print(f"       - Matched to ground truth: {matched_spike_count:,}")
    print(f"       - Ground truth total spikes: {total_gt_spikes:,}")
    print(f"       - Coverage (matched / ground truth): {coverage * 100:.2f}%")

    dataset = CustomDataset(all_windows, labels)

    batch_size = 1024 
    val_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    print("Data preprocessing completed!")
    for trail in range(1, 6):
        print(f"\n[INFO] === Trail {trail}/5 ===")
        criterion = nn.BCELoss()  

        model = torch.load(f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/train_results/trail_{trail}.pth', weights_only=False)
        model = model.to(device)

        correct = 0
        total = 0

        true_positive = 0
        true_negative = 0
        false_positive = 0
        false_negative = 0

        accuracy_list = []  
        tpr_list = []
        tnr_list = []

        model.eval()

        with torch.no_grad():
            for batch_data, batch_labels in val_loader:
                batch_labels = batch_labels.float().unsqueeze(1)
                batch_data = batch_data.to(device)
                batch_labels = batch_labels.to(device)

                outputs = model(batch_data)
                predicted = (outputs > 0.5).float()  
                total += batch_labels.size(0)
                correct += (predicted == batch_labels).sum().item()
                true_positive += ((predicted == 1) & (batch_labels == 1)).sum().item()
                true_negative += ((predicted == 0) & (batch_labels == 0)).sum().item()
                false_positive += ((predicted == 1) & (batch_labels == 0)).sum().item()
                false_negative += ((predicted == 0) & (batch_labels == 1)).sum().item()

        tpr = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0
        tnr = true_negative / (true_negative + false_positive) if (true_negative + false_positive) > 0 else 0
        accuracy = correct / total if total > 0 else 0

        tpr_dict[date].append(tpr)
        tnr_dict[date].append(tnr)
        accuracy_dict[date].append(accuracy)
        
        print(f"[Trail {trail}] Accuracy: {accuracy * 100:.2f}% | TPR: {tpr * 100:.2f}% | TNR: {tnr * 100:.2f}%")
# Out:
# Processing date: 022522
# [INFO] Total frames: 26,000,100 | Chunk size: 300,000 | Window size: 31
# [INFO] Processing 87 chunks...
# Detecting spikes: 100%|██████████| 87/87 [04:29<00:00,  3.10s/chunk]
# [INFO] Extracted 5,958,425 candidate spikes before deduplication
# [INFO] Deduplicating by time point...
# [INFO] After deduplication: 5,958,425 spikes (removed 0 duplicates)
# [INFO] Spike detection summary:
#        - Detected spikes: 5,958,425
#        - Matched to ground truth: 1,012,734
#        - Ground truth total spikes: 1,044,049
#        - Coverage (matched / ground truth): 97.00%
# Data preprocessing completed!
#
# [INFO] === Trail 1/5 ===
# [Trail 1] Accuracy: 82.17% | TPR: 62.25% | TNR: 86.26%
#
# [INFO] === Trail 2/5 ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 123
#     120 model.eval()
#     122 with torch.no_grad():
# ...

# %%
pd.read_csv()

# %%
import pickle
with open("/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/eval_results/tpr_dict.pkl", "wb") as f:
    pickle.dump(tpr_dict, f)

with open("/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/eval_results/tnr_dict.pkl", "wb") as f:
    pickle.dump(tnr_dict, f)

with open("/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/eval_results/accuracy_dict.pkl", "wb") as f:
    pickle.dump(accuracy_dict, f)

# %% [markdown]
# - Figure Generation

# %%
import umap
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.colors import ListedColormap

# %%
for date in eval_date_list:
    pdf_path = f'figure/embedding_visualization_{date}.pdf'
    with PdfPages(pdf_path) as pdf:

        print(f"Processing date: {date}")

        recording_raw = se.read_blackrock(file_path=f'/media/ubuntu/sda/data/mouse6/ns4/natural_image/mouse6_{date}_natural_image_001.ns4')
        recording_recorded = recording_raw.remove_channels(["98", '31', '32'])

        recording_f = spre.bandpass_filter(recording_recorded, freq_min=300, freq_max=3000)
        recording_f = spre.common_reference(recording_f, reference="global", operator="median")
        spike_inf = pd.read_csv(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_results/{date}/spike_inf.csv")

        total_frames = int(recording_f.get_total_duration() * 10000)
        chunk_size = 100000  
        window_size = 31
        half_window = window_size // 2
        
        input_size = 30 * 31
        hidden_size1 = 128
        hidden_size2 = 32
        output_size = 1  
        device = 'cuda'
        

        criterion = nn.BCELoss()  

        model = torch.load(f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/train_results/trail_1.pth', weights_only=False)
        model = model.to(device)

        start_frame = 0
        all_valid_indices = []
        all_windows = []
        end_frame = min(start_frame + chunk_size, total_frames)
        
        data_chunk = recording_f.get_traces(
            start_frame=start_frame,
            end_frame=end_frame
        )  # shape: (n_channels, chunk_size)
        
        threshold_result = detect_local_minimum_in_window(
            data_chunk.T,
            std_multiplier=2.5,
            window_size=15,
            overlap_ratio=1/3
        )
        
        threshold_result = np.array(threshold_result) + start_frame
        valid_indices = threshold_result[
            (threshold_result >= start_frame + half_window + 1) &
            (threshold_result < end_frame - half_window)
        ]
        
        for idx in valid_indices:
            rel_idx = idx - start_frame
            window = data_chunk.T[:, rel_idx - half_window: rel_idx + half_window + 1]
            all_windows.append(window)
        
        all_valid_indices.extend(valid_indices)

        all_valid_indices = np.array(all_valid_indices)
        all_windows = np.stack(all_windows)
        original_count = len(all_valid_indices)
        
        # 按时间点去重：同一时间点只保留一个检测
        unique_indices, unique_positions = np.unique(all_valid_indices, return_index=True)
        all_valid_indices = unique_indices
        all_windows = all_windows[unique_positions]

        labels = label_array1_based_on_array2(all_valid_indices, spike_inf['time'], threshold=2)

        dataset = CustomDataset(all_windows, labels)

        batch_size = 1024 
        val_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)


        model.eval()
        embeddings = []
        true_labels = []
        predicted_labels = []

        with torch.no_grad():
            for batch_data, batch_labels in val_loader:
                batch_labels = batch_labels.float().unsqueeze(1)
                batch_data = batch_data.to(device)
                batch_labels = batch_labels.to(device)

                outputs = model(batch_data)  
                predicted = (outputs > 0.5).float()  

                x = batch_data.reshape(-1, 30 * 31)
                x = model.fc1(x)
                x = model.relu1(x)
                x = model.fc2(x)
                x = model.relu2(x)
                x = model.fc3(x)
                embeddings.append(x.cpu().numpy())
                true_labels.append(batch_labels.cpu().numpy())
                predicted_labels.append(predicted.cpu().numpy())

        embeddings = np.vstack(embeddings)
        true_labels = np.vstack(true_labels).flatten()
        predicted_labels = np.vstack(predicted_labels).flatten()

        umap_model = umap.UMAP(n_components=2, random_state=42)
        embeddings_2d = umap_model.fit_transform(embeddings)

        custom_cmap = ListedColormap(['lightgray', 'orange'])

        plt.figure(figsize=(8, 8))
        plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=true_labels, cmap=custom_cmap, alpha=1, s = 2)
        plt.title(f"{date} UMAP Visualization - True Labels")
        plt.grid(False)
        pdf.savefig()  
        plt.close()

        plt.figure(figsize=(8, 8))
        plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=predicted_labels, cmap=custom_cmap, alpha=1, s = 2)
        plt.title(f"{date} UMAP Visualization - Predicted Labels")
        plt.grid(False)
        pdf.savefig()  
        plt.close()

        print(f"Visualization saved to {pdf_path}")
# Out:
# Processing date: 021322
# Visualization saved to figure/embedding_visualization_021322.pdf
# Processing date: 022522
# Visualization saved to figure/embedding_visualization_022522.pdf
# Processing date: 031722
# Visualization saved to figure/embedding_visualization_031722.pdf
# Processing date: 042422
# Visualization saved to figure/embedding_visualization_042422.pdf
# Processing date: 052422
# Visualization saved to figure/embedding_visualization_052422.pdf
# Processing date: 062422
# Visualization saved to figure/embedding_visualization_062422.pdf
# Processing date: 072322
# Visualization saved to figure/embedding_visualization_072322.pdf
# Processing date: 082322
# Visualization saved to figure/embedding_visualization_082322.pdf
# Processing date: 092422
# Visualization saved to figure/embedding_visualization_092422.pdf
# Processing date: 102122
# Visualization saved to figure/embedding_visualization_102122.pdf
# Processing date: 112022
# ...

# %%
# 对trainset (021322)进行评估，提取fc3层特征并进行降维可视化
# 观察spike_detection的fc3层能否把各个spike的cluster区分开来

date = '021322'
pdf_path = f'figure/embedding_visualization_cluster_{date}.pdf'

with PdfPages(pdf_path) as pdf:
    print(f"Processing trainset: {date}")

    recording_raw = se.read_blackrock(file_path=f'/media/ubuntu/sda/data/mouse6/ns4/natural_image/mouse6_{date}_natural_image_001.ns4')
    recording_recorded = recording_raw.remove_channels(["98", '31', '32'])

    recording_f = spre.bandpass_filter(recording_recorded, freq_min=300, freq_max=3000)
    recording_f = spre.common_reference(recording_f, reference="global", operator="median")
    spike_inf = pd.read_csv(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_new/021322/spike_inf.tsv", sep = '\t', index_col=0)

    total_frames = int(recording_f.get_total_duration() * 10000)
    chunk_size = 1000000  
    window_size = 31
    half_window = window_size // 2
    
    input_size = 30 * 31
    hidden_size1 = 128
    hidden_size2 = 32
    output_size = 1  
    device = 'cuda'
    
    criterion = nn.BCELoss()  
    model = torch.load(f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/train_results/trail_1.pth', weights_only=False)
    model = model.to(device)

    start_frame = 0
    all_valid_indices = []
    all_windows = []
    end_frame = min(start_frame + chunk_size, total_frames)
    
    data_chunk = recording_f.get_traces(
        start_frame=start_frame,
        end_frame=end_frame
    )  # shape: (n_channels, chunk_size)
    
    threshold_result = detect_local_minimum_in_window(
        data_chunk.T,
        std_multiplier=2.5,
        window_size=15,
        overlap_ratio=1/3
    )
    
    threshold_result = np.array(threshold_result) + start_frame
    valid_indices = threshold_result[
        (threshold_result >= start_frame + half_window + 1) &
        (threshold_result < end_frame - half_window)
    ]
    
    for idx in valid_indices:
        rel_idx = idx - start_frame
        window = data_chunk.T[:, rel_idx - half_window: rel_idx + half_window + 1]
        all_windows.append(window)
    
    all_valid_indices.extend(valid_indices)

    all_valid_indices = np.array(all_valid_indices)
    all_windows = np.stack(all_windows)
    
    # 按时间点去重：同一时间点只保留一个检测
    unique_indices, unique_positions = np.unique(all_valid_indices, return_index=True)
    all_valid_indices = unique_indices
    all_windows = all_windows[unique_positions]

    # 根据cluster信息进行标记
    # spike_inf.csv 的结构: cluster(0), position_1(1), position_2(2), templates(3), time(4), ...
    # cluster_label_array1_based_on_array2 期望第5列是time，第1列是cluster
    # 创建一个符合要求的DataFrame
    spike_inf_for_labeling = pd.DataFrame(np.zeros((len(spike_inf), 6)))
    spike_inf_for_labeling.iloc[:, 1] = spike_inf['cluster_id'].values  # cluster放在第1列
    spike_inf_for_labeling.iloc[:, 5] = spike_inf['time'].values     # time放在第5列
    cluster_labels = cluster_label_array1_based_on_array2(all_valid_indices, spike_inf_for_labeling, threshold=2)
    cluster_labels = np.array(cluster_labels)

    # 只保留有cluster标签的样本（cluster_labels != 0）
    valid_mask = cluster_labels != 0
    all_windows_filtered = all_windows[valid_mask]
    cluster_labels_filtered = cluster_labels[valid_mask]
    
    print(f"Total detected spikes: {len(all_windows)}")
    print(f"Spikes with cluster labels: {len(all_windows_filtered)}")
    print(f"Number of unique clusters: {len(np.unique(cluster_labels_filtered))}")
    print(f"Cluster distribution: {np.bincount(cluster_labels_filtered)}")

    # 创建数据集并提取fc3层特征
    dataset = CustomDataset(all_windows_filtered, cluster_labels_filtered)
    batch_size = 1024 
    val_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    model.eval()
    embeddings_fc3 = []
    cluster_labels_list = []

    with torch.no_grad():
        for batch_data, batch_labels in val_loader:
            batch_data = batch_data.to(device)
            
            # 提取到fc3层的特征
            x = batch_data.reshape(-1, 30 * 31)
            x = model.fc1(x)
            x = model.relu1(x)
            x = model.fc2(x)
            x = model.relu2(x)
            x = model.fc3(x)  # fc3层特征
            
            embeddings_fc3.append(x.cpu().numpy())
            cluster_labels_list.append(batch_labels.numpy())

    embeddings_fc3 = np.vstack(embeddings_fc3)
    cluster_labels_array = np.concatenate(cluster_labels_list)

    print(f"Extracted fc3 embeddings shape: {embeddings_fc3.shape}")
    print(f"Cluster labels shape: {cluster_labels_array.shape}")

    # 采样10000个点
    n_samples = 10000
    np.random.seed(42)  # 设置随机种子以确保可重现性
    if len(embeddings_fc3) > n_samples:
        # 分层采样，确保每个cluster都有代表性
        unique_clusters = np.unique(cluster_labels_array)
        sampled_indices = []
        samples_per_cluster = n_samples // len(unique_clusters)
        remaining_samples = n_samples % len(unique_clusters)
        
        for i, cluster_id in enumerate(unique_clusters):
            cluster_mask = cluster_labels_array == cluster_id
            cluster_indices = np.where(cluster_mask)[0]
            
            if len(cluster_indices) > samples_per_cluster:
                if i < remaining_samples:
                    n_to_sample = samples_per_cluster + 1
                else:
                    n_to_sample = samples_per_cluster
                sampled_cluster_indices = np.random.choice(cluster_indices, size=n_to_sample, replace=False)
            else:
                sampled_cluster_indices = cluster_indices
                
            sampled_indices.extend(sampled_cluster_indices)
        
        sampled_indices = np.array(sampled_indices)
        embeddings_fc3_sampled = embeddings_fc3[sampled_indices]
        cluster_labels_sampled = cluster_labels_array[sampled_indices]
        
        print(f"Sampled {len(embeddings_fc3_sampled)} points from {len(embeddings_fc3)} total points")
    else:
        embeddings_fc3_sampled = embeddings_fc3
        cluster_labels_sampled = cluster_labels_array
        print(f"Using all {len(embeddings_fc3_sampled)} points (less than {n_samples})")

    # 使用UMAP进行降维
    print("Performing UMAP dimensionality reduction...")
    umap_model = umap.UMAP(n_components=2, random_state=42, n_neighbors=15, min_dist=0.1)
    embeddings_2d = umap_model.fit_transform(embeddings_fc3_sampled)

    # 可视化不同cluster的分布
    unique_clusters = np.unique(cluster_labels_sampled)
    n_clusters = len(unique_clusters)
    
    # 为每个cluster分配颜色
    colors = plt.cm.tab20(np.linspace(0, 1, n_clusters))
    cluster_color_map = dict(zip(unique_clusters, colors))

    fig, ax = plt.subplots(figsize=(12, 10))
    
    # 绘制每个cluster的点
    for i, cluster_id in enumerate(unique_clusters):
        cluster_mask = cluster_labels_sampled == cluster_id
        ax.scatter(embeddings_2d[cluster_mask, 0], 
                  embeddings_2d[cluster_mask, 1], 
                  c=[colors[i]], 
                  label=f'Cluster {cluster_id}',
                  alpha=0.6, 
                  s=10)
    
    ax.set_title(f'{date} UMAP Visualization of fc3 Features by Cluster\n(Sampled {len(embeddings_fc3_sampled)} points)')
    ax.set_xlabel('UMAP Component 1')
    ax.set_ylabel('UMAP Component 2')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8, ncol=2)
    ax.grid(False)
    plt.tight_layout()
    pdf.savefig(fig, bbox_inches='tight')
    plt.close()

    print(f"Visualization saved to {pdf_path}")
# Out:
# Processing trainset: 021322
# Total detected spikes: 222395
# Spikes with cluster labels: 89565
# Number of unique clusters: 43
# Cluster distribution: [   0 1686 1797 3274  913  666    0    0  430    0    0  693 4134    0
#     0    0 2459 1609    0    0 1119  737 1024    0  296  612    0  407
#   741    0 3279 3630    0 1060 4494 2235 3780    0    0    0 2190    0
#  1190 1140 1341 1571    0    0 1680 1038  992 1587 3409 1455 5083 2790
#     0 1669 3872    0    0 2351    0    0 4969    0    0    0    0 2872
#  4176 3115]
# Extracted fc3 embeddings shape: (89565, 16)
# Cluster labels shape: (89565,)
# Sampled 10000 points from 89565 total points
# Performing UMAP dimensionality reduction...
# Visualization saved to figure/embedding_visualization_cluster_021322.pdf

# %%
spike_inf
# Out:
#         \tcluster_id\ttime\tbest_channel
# 0                        1\t28\t22\t19.0
# 1                        2\t31\t25\t24.0
# 2                         3\t54\t34\t0.0
# 3                          4\t4\t49\t0.0
# 4                         5\t54\t50\t0.0
# ...                                  ...
# 1537494      1654391\t34\t40000010\t26.0
# 1537495       1654392\t64\t40000016\t8.0
# 1537496       1654393\t58\t40000028\t8.0
# 1537497       1654395\t12\t40000043\t7.0
# 1537498      1654396\t16\t40000093\t13.0
#
# [1537499 rows x 1 columns]
