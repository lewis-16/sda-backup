# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages

from tqdm import tqdm

from sklearn.decomposition import PCA
import umap
import random

import sys
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.preprocessing as spre

import matplotlib.pyplot as plt
import json

from probeinterface import write_prb, read_prb

import torch.nn.functional as F
from pathlib import Path

import pickle

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split, Subset
from sklearn.metrics import accuracy_score
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances

# %%
channel_position = {
    0: [650, 0],
    2: [650, 50],
    4: [650, 100],
    6: [600, 100],
    8: [600, 50],
    10: [600, 0],
    1: [0, 0],
    3: [0, 50],
    5: [0, 100],
    7: [50, 100],
    9: [50, 50],
    11: [50, 0],
    13: [150, 200], 
    15: [150, 250],
    17: [150, 300],
    19: [200, 300],
    21: [200, 250],
    23: [200, 200],
    12: [500, 200],
    14: [500, 250],
    16: [500, 300],
    18: [450, 300],
    20: [450, 250],
    22: [450, 200],
    24: [350, 400],
    26: [350, 450],
    28: [350, 500],
    25: [300, 400],
    27: [300, 450],
    29: [300, 500]}

channel_indices = {
        "1": [1, 3, 5, 7, 9, 11],
        "2": [13, 15, 17, 19, 21, 23],
        "3": [24, 25, 26, 27, 28, 29],
        "4": [12, 14, 16, 18, 20, 22],
        "5": [0, 2, 4, 6, 8, 10]
        }

# %%
def count_array2_in_range_of_array1(array1, array2, threshold=5):

    sorted_array1 = np.sort(array1)
    
    lefts = array2 - threshold
    rights = array2 + threshold
    
    left_indices = np.searchsorted(sorted_array1, lefts, side='left')
    
    right_indices = np.searchsorted(sorted_array1, rights, side='right')
    
    has_within_range = right_indices > left_indices
    
    count = np.sum(has_within_range)
    
    return count


def detect_local_minimum_in_window(data, window_size=20, std_multiplier=2):

    """
    在每个滑动窗口范围内检测局部最小值的索引，并确保最小值低于 mean - std_multiplier * std。

    参数:
    data : numpy.ndarray
        输入数据，形状为 (n_rows, n_columns)。
    window_size : int
        滑动窗口的大小，用于定义局部范围，默认为 20。
    std_multiplier : float
        标准差的倍数，用于筛选局部最小值，默认为 2。

    返回:
    local_minima_indices : list of numpy.ndarray
        每行局部最小值的索引列表，每个元素是对应行局部最小值的索引数组。
    """
    local_minima_indices = []

    for row in data:
        minima_indices = []
        row = row.astype(np.float32)
        row_mean = np.mean(row)
        row_std = np.std(row)
        threshold = row_mean - std_multiplier * row_std

        for start in range(0, len(row), window_size):
            end = min(start + window_size, len(row))
            window = row[start:end]
            
            if len(window) > 0:
                local_min_index = np.argmin(window)
                local_min_value = window[local_min_index]
                
                if local_min_value < threshold:
                    minima_indices.append(start + local_min_index)  
        
        local_minima_indices.extend(minima_indices)
        local_minima_indices = list(set(local_minima_indices))  

    return local_minima_indices


def cluster_label_array1_based_on_array2(array1, array2, threshold=5, 
                                         cluster_column='cluster'):

    """
    根据 array2 的 'time' 和 'cluster' 对 array1 进行标记。
    如果 array1 中的某个值在 threshold 范围内存在于 array2 的 'time' 中，则标记为对应的 'cluster' 值，否则为 0。
    
    参数:
    array1 : numpy.ndarray
        要标记的数组。
    array2 : numpy.ndarray
        包含 'time' 和 'cluster' 的二维数组。
        第一列为 'time'，第二列为 'cluster'。
    threshold : int
        判断范围的阈值。
    
    返回:
    labels : numpy.ndarray
        长度为 len(array1) 的标签数组，值为 array2 中的 'cluster' 或 0。
    """

    array2 = np.array((array2['time'], array2[cluster_column])).T
    sorted_indices = np.argsort(array2[:, 0])
    sorted_array2 = array2[sorted_indices]
    
    labels = -np.ones(len(array1), dtype=int)
    
    # 遍历 array1 中的每个元素
    for i, value in enumerate(array1):
        # 计算当前值的范围
        left = value - threshold
        right = value + threshold
        
        left_index = np.searchsorted(sorted_array2[:, 0], left, side='left')
        right_index = np.searchsorted(sorted_array2[:, 0], right, side='right')
        
        # 如果范围内存在值，则标记为对应的 'cluster'
        if right_index > left_index:
            # 获取范围内的第一个匹配值的 'cluster'
            labels[i] = sorted_array2[left_index, 1]
    
    return labels


def label_array1_based_on_array2(array1, array2, threshold=5):

    """
    根据 array2 的值对 array1 进行标记。
    如果 array1 中的某个值在 threshold 范围内存在于 array2 中，则标记为 1，否则为 0。
    
    参数:
    array1 : numpy.ndarray
        要标记的数组。
    array2 : numpy.ndarray
        用于判断的数组。
    threshold : int
        判断范围的阈值。
    
    返回:
    labels : numpy.ndarray
        长度为 len(array1) 的标签数组，值为 0 或 1。
    """
    # 对 array2 进行排序以加速搜索
    sorted_array2 = np.sort(array2)
    
    # 初始化标签数组，默认值为 0
    labels = np.zeros(len(array1), dtype=int)
    
    # 遍历 array1 中的每个元素
    for i, value in enumerate(array1):
        # 计算当前值的范围
        left = value - threshold
        right = value + threshold
        
        # 使用二分搜索判断范围内是否存在值
        left_index = np.searchsorted(sorted_array2, left, side='left')
        right_index = np.searchsorted(sorted_array2, right, side='right')
        
        # 如果范围内存在值，则标记为 1
        if right_index > left_index:
            labels[i] = 1
    
    return labels


def extract_windows(data, indices, window_size=61):
    """
    根据给定的时间点索引提取窗口。
    
    参数:
    data : numpy.ndarray
        输入数据，形状为 (n_channels, time)
    indices : numpy.ndarray
        时间点索引数组，用于指定需要提取窗口的中心点
    window_size : int
        窗口长度，默认为61（对应time-30到time+31）
    
    返回:
    windows : numpy.ndarray
        提取的窗口数据，形状为 (len(indices), n_channels, window_size)
    """
    n_channels, time_length = data.shape
    half_window = window_size // 2

    if np.any(indices < half_window) or np.any(indices >= time_length - half_window):
        raise ValueError("Some indices are out of bounds for the given window size.")

    windows = []
    for idx in indices:
        window = data[:, idx - half_window:idx + half_window + 1]
        windows.append(window)

    windows = np.array(windows)
    return windows
def calculate_position(row):
    probe_group = str(row['probe_group'])
    channels = channel_indices[probe_group]
    waveform = row['waveform'] 
    
    a_squared = [np.sum(waveform[:, j]**2) for j in range(len(channels))]
    
    sum_x_a = 0
    sum_y_a = 0
    sum_a = 0
    
    for j, channel in enumerate(channels):
        x_i, y_i = channel_position.get(channel, [0, 0])  
        a_i_sq = a_squared[j]
        
        sum_x_a += x_i * a_i_sq
        sum_y_a += y_i * a_i_sq
        sum_a += a_i_sq
    
    if sum_a == 0:
        return pd.Series({'position_1': 0, 'position_2': 0})
    
    x_hat = sum_x_a / sum_a
    y_hat = sum_y_a / sum_a
    return pd.Series({'position_1': x_hat, 'position_2': y_hat})

def calculate_position_waveform(row, channel_position, channel_indices, power=2):
    x_target = row['position_1']
    y_target = row['position_2']
    probe_group = str(row['probe_group'])
    channels = channel_indices[probe_group]  
    waveforms = row['waveform']  
    
    distances = []
    for channel in channels:
        x_channel, y_channel = channel_position.get(channel, [np.nan, np.nan])
        if np.isnan(x_channel):  
            continue
        distance = np.sqrt((x_target - x_channel)**2 + (y_target - y_channel)**2)
        distances.append(distance)
    
    if not distances:  
        return np.zeros(31)
    
    #IDW
    weights = 1 / (np.array(distances) ** power)
    if np.any(distances == 0):
        zero_idx = np.argwhere(distances == 0).flatten()
        return waveforms[:, zero_idx[0]]
    
    weights /= np.sum(weights)
    
    synthesized_waveform = np.zeros(31)
    for t in range(31): 
        weighted_sum = np.dot(waveforms[t, :], weights)
        synthesized_waveform[t] = weighted_sum
    
    return synthesized_waveform


def compute_cluster_average(sample_data, potent_spike_inf, cluster_column='cluster_predicted'):
    """
    计算 potent_spike_inf 中每个 cluster_predicted 对应的 sample_data 的平均值。
    
    参数:
    - sample_data: np.ndarray, 输入的 (n, 30, 61) 矩阵。
    - potent_spike_inf: pd.DataFrame, 包含 cluster_predicted 信息的 DataFrame。
    - cluster_column: str, cluster 信息所在的列名。
    
    返回:
    - cluster_averages: dict, 每个 cluster 对应的平均值矩阵 (30, 61)。
    """
    cluster_averages = {}
    unique_clusters = potent_spike_inf[cluster_column].unique()
    
    for cluster in unique_clusters:
        cluster_indices = potent_spike_inf[potent_spike_inf[cluster_column] == cluster].index
        cluster_average = sample_data[cluster_indices].mean(axis=0) 
        cluster_averages[cluster] = cluster_average
    
    return cluster_averages

def judge_cluster_reality(row, neuron_inf):
    from scipy.stats import pearsonr

    position_threshold =30
    position_condition = (
        (abs(neuron_inf['position_1'] - row['position_1']) <= position_threshold) &
        (abs(neuron_inf['position_2'] - row['position_2']) <= position_threshold)
    )

    candidate_neurons = neuron_inf[position_condition]

    if candidate_neurons.empty:
        return None

    waveform_threshold = 0.9
    row_waveform = row['position_waveform']
    best_match = None
    best_corr = -1 

    for _, candidate in candidate_neurons.iterrows():
        neuron_inf_waveform = candidate['position_waveform'][15:-15]
        corr, _ = pearsonr(row_waveform, neuron_inf_waveform)

        if corr > waveform_threshold and corr > best_corr:
            best_corr = corr
            best_match = candidate['cluster']

    return best_match if best_match is not None else None


def process_cluster_averages(cluster_averages, channel_indices):
    """
    对 cluster_averages 中的每个 item，找到最大值所在的通道，
    并根据 channel_indices 保留对应的 6 个通道。
    
    参数:
    - cluster_averages: dict, 每个 cluster 的平均值 (30, 61)。
    - channel_indices: dict, 通道索引字典。
    
    返回:
    - processed_averages: dict, 处理后的字典，键为 cluster_channelindices，值为 (6, 61) 的数组。
    """
    processed_averages = {}
    
    for cluster, avg_matrix in cluster_averages.items():
        max_channel = np.argmax(avg_matrix.max(axis=1))  
        
        for key, indices in channel_indices.items():
            if max_channel in indices:
                selected_channels = avg_matrix[indices, :]
                new_key = f"{cluster}_{key}"
                processed_averages[new_key] = selected_channels
                break
    
    return processed_averages

def predict_new(feature, kmeans):
    dists = pairwise_distances(feature, kmeans.cluster_centers_ )
    return np.argmin(dists, axis=1)

# %% [markdown]
# ## Model Train

# %%
class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        self.labels = torch.tensor(self.labels, dtype=torch.long)
        return self.data[idx].astype(np.float32), self.labels[idx]

class Spike_Classification_MLP(nn.Module):
    """
    使用Supervised Contrastive Learning的MLP模型
    包含特征提取层、投影头（用于对比学习）和分类头
    """
    def __init__(self, input_size, hidden_size1, hidden_size2, num_classes, proj_dim=128):
        super(Spike_Classification_MLP, self).__init__()
        # 特征提取层
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        
        # 投影头：用于contrastive learning
        # 将特征投影到更低维的空间进行对比学习
        self.projection = nn.Sequential(
            nn.Linear(hidden_size2, hidden_size2),
            nn.ReLU(),
            nn.Linear(hidden_size2, proj_dim)
        )
        
        # 分类头
        self.fc3 = nn.Linear(hidden_size2, num_classes)
    
    def forward(self, x, mode='train'):
        """
        Args:
            x: 输入数据
            mode: 'train' 训练模式返回投影特征和logits
                  'eval' 评估模式只返回特征
        """
        x = x.reshape(-1, 31 * 30)
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        features = self.relu2(x)  # 这是用于聚类的特征（hidden_size2维）
        
        if mode == 'train':
            # 训练时返回：投影特征（用于对比学习）、logits（用于分类）、原始特征
            proj_features = self.projection(features)
            logits = self.fc3(features)
            return proj_features, logits, features
        else:
            # 评估/推理时只返回特征向量
            return features

# %%
recording_raw = se.read_blackrock(file_path='/media/ubuntu/sda/data/mouse6/ns4/natural_image/mouse6_021322_natural_image_001.ns4')
recording_recorded = recording_raw.remove_channels(["98", '31', '32'])

recording_f = spre.bandpass_filter(recording_recorded, freq_min=300, freq_max=3000)
recording_f = spre.common_reference(recording_f, reference="global", operator="median")

spike_inf = pd.read_csv("/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_results/021322/spike_inf.csv")
removed_spikes = spike_inf['cluster'].value_counts()
removed_spikes = removed_spikes[removed_spikes < 8000].index
spike_inf = spike_inf[~spike_inf['cluster'].isin(removed_spikes)]

# %%
total_frames = int(recording_f.get_total_duration() * 10000)
chunk_size = 100000  
window_size = 31
half_window = window_size // 2

all_valid_indices = []
all_windows = []

for start_frame in range(0, total_frames, chunk_size):
    end_frame = min(start_frame + chunk_size, total_frames)
    
    data_chunk = recording_f.get_traces(
        start_frame=start_frame,
        end_frame=end_frame
    )  
    
    threshold_result = detect_local_minimum_in_window(
            data_chunk.T,
            std_multiplier=3.5,
            window_size= 30
        )
    
    threshold_result = np.array(threshold_result) + start_frame
    valid_indices = threshold_result[
        (threshold_result >= start_frame + half_window + 1) & 
        (threshold_result < end_frame - half_window)
    ]
    
    for idx in valid_indices:
        rel_idx = idx - start_frame
        window = data_chunk.T[:, rel_idx-half_window : rel_idx+half_window+1]
        all_windows.append(window)
    
    all_valid_indices.extend(valid_indices)

all_valid_indices = np.array(all_valid_indices)
all_windows = np.stack(all_windows)  

cluster_labels = cluster_label_array1_based_on_array2(all_valid_indices, spike_inf, threshold=1)

valid_indices = cluster_labels != -1
all_windows = all_windows[valid_indices]
cluster_labels = cluster_labels[valid_indices]

# %%
potent_spike_inf = pd.DataFrame((all_valid_indices[valid_indices], cluster_labels), index= ['time', 'cluster']).T
# potent_spike_inf = potent_spike_inf[potent_spike_inf['cluster'] != -1]

unique_clusters = np.unique(potent_spike_inf['cluster'])
cluster_to_index = {cluster: idx for idx, cluster in enumerate(unique_clusters)}
potent_spike_inf['cluster_rep'] = np.array([cluster_to_index[cluster] for cluster in potent_spike_inf['cluster']])

# %%
indices = potent_spike_inf['time'].values

labels = potent_spike_inf['cluster_rep'].values

balanced_indices = []
for cluster in potent_spike_inf['cluster_rep'].unique():
    cluster_indices = np.where(labels == cluster)[0]
    if len(cluster_indices) > 8000:
        sampled_indices = np.random.choice(cluster_indices, 8000, replace=False)
    else:
        sampled_indices = cluster_indices
    balanced_indices.extend(sampled_indices)

np.random.shuffle(balanced_indices)

balanced_data = all_windows[balanced_indices]
balanced_labels = labels[balanced_indices]

dataset = CustomDataset(balanced_data, balanced_labels)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

batch_size = 1024
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for trail in range(1, 2):
    device = 'cuda'
    input_size = balanced_data.shape[1] * balanced_data.shape[2]
    hidden_size1 = 64
    hidden_size2 = 50
    num_classes = potent_spike_inf['cluster_rep'].nunique()
    proj_dim = 128  # 投影维度
    
    # 创建模型
    model = Spike_Classification_MLP(input_size, hidden_size1, hidden_size2, num_classes, proj_dim)
    model = model.to(device)

    criterion_ce = nn.CrossEntropyLoss()
    
    optimizer = optim.Adam(model.parameters(), lr=0.00001)

    # 损失权重超参数
    
    num_epochs = 210
    accuracy_best = 0
    i = 0
    
    for epoch in range(num_epochs):
        # ====== 训练阶段 ======
        all_labels = []
        all_predictions = []
        model.train()
        
        for batch_data, batch_labels in train_loader:
            batch_data = batch_data.to(device)
            batch_labels = batch_labels.to(device)

            # 前向传播：获取投影特征（用于对比学习）、logits（用于分类）和原始特征
            _, logits, _ = model(batch_data, mode='train')
            
            # 计算两个损失
            ce_loss = criterion_ce(logits, batch_labels)

            # 反向传播
            optimizer.zero_grad()
            ce_loss.backward()
            optimizer.step()

            predicted = torch.argmax(logits, dim=1)
            all_labels.extend(batch_labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

        train_accuracy = accuracy_score(all_labels, all_predictions)

        # ====== 验证阶段 ======
        model.eval()
        all_labels = []
        all_predictions = []
        with torch.no_grad():
            for batch_data, batch_labels in test_loader:
                batch_data = batch_data.to(device)
                batch_labels = batch_labels.to(device)

                _, logits, _ = model(batch_data, mode='train')
                predicted = torch.argmax(logits, dim=1)

                all_labels.extend(batch_labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())

        all_labels = np.array(all_labels)
        all_predictions = np.array(all_predictions)

        accuracy = accuracy_score(all_labels, all_predictions)
        
        # 每10个epoch打印详细信息
        if epoch % 1 == 0:
            print(f"Trail {trail} - Epoch [{epoch+1}/{num_epochs}]")
            print(f"  Train Acc: {train_accuracy:.4f}, Test Acc: {accuracy:.4f}")
        
        # 保存最佳模型
        if accuracy > accuracy_best:
            accuracy_best = accuracy
            i = 0
            #torch.save(model, f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_classification/train_results/spike_classification_model_{trail}.pth')
            print(f"✓ Best model saved with Accuracy: {accuracy_best:.4f}")
            print("_" * 60)
        else:
            i += 1
            if i == 3:
                print(f"Early stopping after {epoch+1} epochs with best Accuracy: {accuracy_best:.4f}")
                print("_" * 60)
                break
# Out:
# Trail 1 - Epoch [1/210]
#   Train Acc: 0.0448, Test Acc: 0.0541
# ✓ Best model saved with Accuracy: 0.0541
# ____________________________________________________________
# Trail 1 - Epoch [2/210]
#   Train Acc: 0.0744, Test Acc: 0.0969
# ✓ Best model saved with Accuracy: 0.0969
# ____________________________________________________________
# Trail 1 - Epoch [3/210]
#   Train Acc: 0.1234, Test Acc: 0.1452
# ✓ Best model saved with Accuracy: 0.1452
# ____________________________________________________________
# Trail 1 - Epoch [4/210]
#   Train Acc: 0.1732, Test Acc: 0.1923
# ✓ Best model saved with Accuracy: 0.1923
# ____________________________________________________________
# Trail 1 - Epoch [5/210]
#   Train Acc: 0.2213, Test Acc: 0.2404
# ✓ Best model saved with Accuracy: 0.2404
# ____________________________________________________________
# Trail 1 - Epoch [6/210]
#   Train Acc: 0.2686, Test Acc: 0.2849
# ✓ Best model saved with Accuracy: 0.2849
# ____________________________________________________________
# Trail 1 - Epoch [7/210]
#   Train Acc: 0.3151, Test Acc: 0.3267
# ✓ Best model saved with Accuracy: 0.3267
# ____________________________________________________________
# Trail 1 - Epoch [8/210]
#   Train Acc: 0.3594, Test Acc: 0.3705
# ✓ Best model saved with Accuracy: 0.3705
# ____________________________________________________________
# Trail 1 - Epoch [9/210]
#   Train Acc: 0.4016, Test Acc: 0.4113
# ✓ Best model saved with Accuracy: 0.4113
# ____________________________________________________________
# Trail 1 - Epoch [10/210]
#   Train Acc: 0.4415, Test Acc: 0.4494
# ✓ Best model saved with Accuracy: 0.4494
# ____________________________________________________________
# Trail 1 - Epoch [11/210]
#   Train Acc: 0.4783, Test Acc: 0.4852
# ✓ Best model saved with Accuracy: 0.4852
# ____________________________________________________________
# Trail 1 - Epoch [12/210]
#   Train Acc: 0.5137, Test Acc: 0.5176
# ✓ Best model saved with Accuracy: 0.5176
# ____________________________________________________________
# Trail 1 - Epoch [13/210]
#   Train Acc: 0.5453, Test Acc: 0.5458
# ✓ Best model saved with Accuracy: 0.5458
# ____________________________________________________________
# Trail 1 - Epoch [14/210]
#   Train Acc: 0.5737, Test Acc: 0.5725
# ✓ Best model saved with Accuracy: 0.5725
# ____________________________________________________________
# Trail 1 - Epoch [15/210]
#   Train Acc: 0.5990, Test Acc: 0.5967
# ✓ Best model saved with Accuracy: 0.5967
# ____________________________________________________________
# Trail 1 - Epoch [16/210]
#   Train Acc: 0.6213, Test Acc: 0.6171
# ✓ Best model saved with Accuracy: 0.6171
# ____________________________________________________________
# Trail 1 - Epoch [17/210]
#   Train Acc: 0.6417, Test Acc: 0.6357
# ✓ Best model saved with Accuracy: 0.6357
# ____________________________________________________________
# Trail 1 - Epoch [18/210]
#   Train Acc: 0.6598, Test Acc: 0.6534
# ✓ Best model saved with Accuracy: 0.6534
# ____________________________________________________________
# Trail 1 - Epoch [19/210]
#   Train Acc: 0.6757, Test Acc: 0.6680
# ✓ Best model saved with Accuracy: 0.6680
# ____________________________________________________________
# Trail 1 - Epoch [20/210]
#   Train Acc: 0.6898, Test Acc: 0.6808
# ✓ Best model saved with Accuracy: 0.6808
# ____________________________________________________________
# Trail 1 - Epoch [21/210]
#   Train Acc: 0.7023, Test Acc: 0.6929
# ✓ Best model saved with Accuracy: 0.6929
# ____________________________________________________________
# Trail 1 - Epoch [22/210]
#   Train Acc: 0.7139, Test Acc: 0.7034
# ✓ Best model saved with Accuracy: 0.7034
# ____________________________________________________________
# Trail 1 - Epoch [23/210]
#   Train Acc: 0.7242, Test Acc: 0.7132
# ✓ Best model saved with Accuracy: 0.7132
# ____________________________________________________________
# Trail 1 - Epoch [24/210]
#   Train Acc: 0.7335, Test Acc: 0.7221
# ✓ Best model saved with Accuracy: 0.7221
# ____________________________________________________________
# Trail 1 - Epoch [25/210]
#   Train Acc: 0.7421, Test Acc: 0.7298
# ✓ Best model saved with Accuracy: 0.7298
# ____________________________________________________________
# Trail 1 - Epoch [26/210]
#   Train Acc: 0.7497, Test Acc: 0.7366
# ✓ Best model saved with Accuracy: 0.7366
# ____________________________________________________________
# Trail 1 - Epoch [27/210]
#   Train Acc: 0.7567, Test Acc: 0.7433
# ✓ Best model saved with Accuracy: 0.7433
# ____________________________________________________________
# Trail 1 - Epoch [28/210]
#   Train Acc: 0.7631, Test Acc: 0.7497
# ✓ Best model saved with Accuracy: 0.7497
# ____________________________________________________________
# Trail 1 - Epoch [29/210]
#   Train Acc: 0.7693, Test Acc: 0.7547
# ✓ Best model saved with Accuracy: 0.7547
# ____________________________________________________________
# Trail 1 - Epoch [30/210]
#   Train Acc: 0.7748, Test Acc: 0.7601
# ✓ Best model saved with Accuracy: 0.7601
# ____________________________________________________________
# Trail 1 - Epoch [31/210]
#   Train Acc: 0.7800, Test Acc: 0.7648
# ✓ Best model saved with Accuracy: 0.7648
# ____________________________________________________________
# Trail 1 - Epoch [32/210]
#   Train Acc: 0.7847, Test Acc: 0.7693
# ✓ Best model saved with Accuracy: 0.7693
# ____________________________________________________________
# Trail 1 - Epoch [33/210]
#   Train Acc: 0.7891, Test Acc: 0.7729
# ✓ Best model saved with Accuracy: 0.7729
# ____________________________________________________________
# Trail 1 - Epoch [34/210]
#   Train Acc: 0.7935, Test Acc: 0.7764
# ✓ Best model saved with Accuracy: 0.7764
# ____________________________________________________________
# Trail 1 - Epoch [35/210]
#   Train Acc: 0.7969, Test Acc: 0.7803
# ✓ Best model saved with Accuracy: 0.7803
# ____________________________________________________________
# Trail 1 - Epoch [36/210]
#   Train Acc: 0.8007, Test Acc: 0.7832
# ✓ Best model saved with Accuracy: 0.7832
# ____________________________________________________________
# Trail 1 - Epoch [37/210]
#   Train Acc: 0.8042, Test Acc: 0.7865
# ✓ Best model saved with Accuracy: 0.7865
# ____________________________________________________________
# Trail 1 - Epoch [38/210]
#   Train Acc: 0.8072, Test Acc: 0.7895
# ✓ Best model saved with Accuracy: 0.7895
# ____________________________________________________________
# Trail 1 - Epoch [39/210]
#   Train Acc: 0.8101, Test Acc: 0.7923
# ✓ Best model saved with Accuracy: 0.7923
# ____________________________________________________________
# Trail 1 - Epoch [40/210]
#   Train Acc: 0.8131, Test Acc: 0.7952
# ✓ Best model saved with Accuracy: 0.7952
# ____________________________________________________________
# Trail 1 - Epoch [41/210]
#   Train Acc: 0.8161, Test Acc: 0.7975
# ✓ Best model saved with Accuracy: 0.7975
# ____________________________________________________________
# Trail 1 - Epoch [42/210]
#   Train Acc: 0.8187, Test Acc: 0.8002
# ✓ Best model saved with Accuracy: 0.8002
# ____________________________________________________________
# Trail 1 - Epoch [43/210]
#   Train Acc: 0.8209, Test Acc: 0.8023
# ✓ Best model saved with Accuracy: 0.8023
# ____________________________________________________________
# Trail 1 - Epoch [44/210]
#   Train Acc: 0.8235, Test Acc: 0.8046
# ✓ Best model saved with Accuracy: 0.8046
# ____________________________________________________________
# Trail 1 - Epoch [45/210]
#   Train Acc: 0.8255, Test Acc: 0.8061
# ✓ Best model saved with Accuracy: 0.8061
# ____________________________________________________________
# Trail 1 - Epoch [46/210]
#   Train Acc: 0.8278, Test Acc: 0.8080
# ✓ Best model saved with Accuracy: 0.8080
# ____________________________________________________________
# Trail 1 - Epoch [47/210]
#   Train Acc: 0.8299, Test Acc: 0.8096
# ✓ Best model saved with Accuracy: 0.8096
# ____________________________________________________________
# Trail 1 - Epoch [48/210]
#   Train Acc: 0.8318, Test Acc: 0.8112
# ✓ Best model saved with Accuracy: 0.8112
# ____________________________________________________________
# Trail 1 - Epoch [49/210]
#   Train Acc: 0.8337, Test Acc: 0.8124
# ✓ Best model saved with Accuracy: 0.8124
# ____________________________________________________________
# Trail 1 - Epoch [50/210]
#   Train Acc: 0.8353, Test Acc: 0.8139
# ✓ Best model saved with Accuracy: 0.8139
# ____________________________________________________________
# Trail 1 - Epoch [51/210]
#   Train Acc: 0.8373, Test Acc: 0.8155
# ✓ Best model saved with Accuracy: 0.8155
# ____________________________________________________________
# Trail 1 - Epoch [52/210]
#   Train Acc: 0.8386, Test Acc: 0.8169
# ✓ Best model saved with Accuracy: 0.8169
# ____________________________________________________________
# Trail 1 - Epoch [53/210]
#   Train Acc: 0.8405, Test Acc: 0.8183
# ✓ Best model saved with Accuracy: 0.8183
# ____________________________________________________________
# Trail 1 - Epoch [54/210]
#   Train Acc: 0.8421, Test Acc: 0.8195
# ✓ Best model saved with Accuracy: 0.8195
# ____________________________________________________________
# Trail 1 - Epoch [55/210]
#   Train Acc: 0.8435, Test Acc: 0.8207
# ✓ Best model saved with Accuracy: 0.8207
# ____________________________________________________________
# Trail 1 - Epoch [56/210]
#   Train Acc: 0.8451, Test Acc: 0.8217
# ✓ Best model saved with Accuracy: 0.8217
# ____________________________________________________________
# Trail 1 - Epoch [57/210]
#   Train Acc: 0.8464, Test Acc: 0.8225
# ✓ Best model saved with Accuracy: 0.8225
# ____________________________________________________________
# Trail 1 - Epoch [58/210]
#   Train Acc: 0.8477, Test Acc: 0.8238
# ✓ Best model saved with Accuracy: 0.8238
# ____________________________________________________________
# Trail 1 - Epoch [59/210]
#   Train Acc: 0.8492, Test Acc: 0.8246
# ✓ Best model saved with Accuracy: 0.8246
# ____________________________________________________________
# Trail 1 - Epoch [60/210]
#   Train Acc: 0.8502, Test Acc: 0.8261
# ✓ Best model saved with Accuracy: 0.8261
# ____________________________________________________________
# Trail 1 - Epoch [61/210]
#   Train Acc: 0.8515, Test Acc: 0.8269
# ✓ Best model saved with Accuracy: 0.8269
# ____________________________________________________________
# Trail 1 - Epoch [62/210]
#   Train Acc: 0.8527, Test Acc: 0.8280
# ✓ Best model saved with Accuracy: 0.8280
# ____________________________________________________________
# Trail 1 - Epoch [63/210]
#   Train Acc: 0.8536, Test Acc: 0.8290
# ✓ Best model saved with Accuracy: 0.8290
# ____________________________________________________________
# Trail 1 - Epoch [64/210]
#   Train Acc: 0.8550, Test Acc: 0.8298
# ✓ Best model saved with Accuracy: 0.8298
# ____________________________________________________________
# Trail 1 - Epoch [65/210]
#   Train Acc: 0.8557, Test Acc: 0.8304
# ✓ Best model saved with Accuracy: 0.8304
# ____________________________________________________________
# Trail 1 - Epoch [66/210]
#   Train Acc: 0.8567, Test Acc: 0.8311
# ✓ Best model saved with Accuracy: 0.8311
# ____________________________________________________________
# Trail 1 - Epoch [67/210]
#   Train Acc: 0.8579, Test Acc: 0.8318
# ✓ Best model saved with Accuracy: 0.8318
# ____________________________________________________________
# Trail 1 - Epoch [68/210]
#   Train Acc: 0.8584, Test Acc: 0.8326
# ✓ Best model saved with Accuracy: 0.8326
# ____________________________________________________________
# Trail 1 - Epoch [69/210]
#   Train Acc: 0.8597, Test Acc: 0.8334
# ✓ Best model saved with Accuracy: 0.8334
# ____________________________________________________________
# Trail 1 - Epoch [70/210]
#   Train Acc: 0.8605, Test Acc: 0.8342
# ✓ Best model saved with Accuracy: 0.8342
# ____________________________________________________________
# Trail 1 - Epoch [71/210]
#   Train Acc: 0.8614, Test Acc: 0.8351
# ✓ Best model saved with Accuracy: 0.8351
# ____________________________________________________________
# Trail 1 - Epoch [72/210]
#   Train Acc: 0.8624, Test Acc: 0.8355
# ✓ Best model saved with Accuracy: 0.8355
# ____________________________________________________________
# Trail 1 - Epoch [73/210]
#   Train Acc: 0.8632, Test Acc: 0.8363
# ✓ Best model saved with Accuracy: 0.8363
# ____________________________________________________________
# Trail 1 - Epoch [74/210]
#   Train Acc: 0.8639, Test Acc: 0.8374
# ✓ Best model saved with Accuracy: 0.8374
# ____________________________________________________________
# Trail 1 - Epoch [75/210]
#   Train Acc: 0.8648, Test Acc: 0.8381
# ✓ Best model saved with Accuracy: 0.8381
# ____________________________________________________________
# Trail 1 - Epoch [76/210]
#   Train Acc: 0.8654, Test Acc: 0.8387
# ✓ Best model saved with Accuracy: 0.8387
# ____________________________________________________________
# Trail 1 - Epoch [77/210]
#   Train Acc: 0.8661, Test Acc: 0.8389
# ✓ Best model saved with Accuracy: 0.8389
# ____________________________________________________________
# Trail 1 - Epoch [78/210]
#   Train Acc: 0.8670, Test Acc: 0.8392
# ✓ Best model saved with Accuracy: 0.8392
# ____________________________________________________________
# Trail 1 - Epoch [79/210]
#   Train Acc: 0.8677, Test Acc: 0.8398
# ✓ Best model saved with Accuracy: 0.8398
# ____________________________________________________________
# Trail 1 - Epoch [80/210]
#   Train Acc: 0.8685, Test Acc: 0.8405
# ✓ Best model saved with Accuracy: 0.8405
# ____________________________________________________________
# Trail 1 - Epoch [81/210]
#   Train Acc: 0.8691, Test Acc: 0.8413
# ✓ Best model saved with Accuracy: 0.8413
# ____________________________________________________________
# Trail 1 - Epoch [82/210]
#   Train Acc: 0.8698, Test Acc: 0.8417
# ✓ Best model saved with Accuracy: 0.8417
# ____________________________________________________________
# Trail 1 - Epoch [83/210]
#   Train Acc: 0.8705, Test Acc: 0.8423
# ✓ Best model saved with Accuracy: 0.8423
# ____________________________________________________________
# Trail 1 - Epoch [84/210]
#   Train Acc: 0.8713, Test Acc: 0.8427
# ✓ Best model saved with Accuracy: 0.8427
# ____________________________________________________________
# Trail 1 - Epoch [85/210]
#   Train Acc: 0.8719, Test Acc: 0.8431
# ✓ Best model saved with Accuracy: 0.8431
# ____________________________________________________________
# Trail 1 - Epoch [86/210]
#   Train Acc: 0.8723, Test Acc: 0.8437
# ✓ Best model saved with Accuracy: 0.8437
# ____________________________________________________________
# Trail 1 - Epoch [87/210]
#   Train Acc: 0.8730, Test Acc: 0.8443
# ✓ Best model saved with Accuracy: 0.8443
# ____________________________________________________________
# Trail 1 - Epoch [88/210]
#   Train Acc: 0.8735, Test Acc: 0.8446
# ✓ Best model saved with Accuracy: 0.8446
# ____________________________________________________________
# Trail 1 - Epoch [89/210]
#   Train Acc: 0.8740, Test Acc: 0.8448
# ✓ Best model saved with Accuracy: 0.8448
# ____________________________________________________________
# Trail 1 - Epoch [90/210]
#   Train Acc: 0.8747, Test Acc: 0.8455
# ✓ Best model saved with Accuracy: 0.8455
# ____________________________________________________________
# Trail 1 - Epoch [91/210]
#   Train Acc: 0.8754, Test Acc: 0.8463
# ✓ Best model saved with Accuracy: 0.8463
# ____________________________________________________________
# Trail 1 - Epoch [92/210]
#   Train Acc: 0.8759, Test Acc: 0.8463
# ✓ Best model saved with Accuracy: 0.8463
# ____________________________________________________________
# Trail 1 - Epoch [93/210]
#   Train Acc: 0.8764, Test Acc: 0.8470
# ✓ Best model saved with Accuracy: 0.8470
# ____________________________________________________________
# Trail 1 - Epoch [94/210]
#   Train Acc: 0.8770, Test Acc: 0.8475
# ✓ Best model saved with Accuracy: 0.8475
# ____________________________________________________________
# Trail 1 - Epoch [95/210]
#   Train Acc: 0.8774, Test Acc: 0.8474
# Trail 1 - Epoch [96/210]
#   Train Acc: 0.8780, Test Acc: 0.8482
# ✓ Best model saved with Accuracy: 0.8482
# ____________________________________________________________
# Trail 1 - Epoch [97/210]
#   Train Acc: 0.8786, Test Acc: 0.8480
# Trail 1 - Epoch [98/210]
#   Train Acc: 0.8789, Test Acc: 0.8484
# ✓ Best model saved with Accuracy: 0.8484
# ____________________________________________________________
# Trail 1 - Epoch [99/210]
#   Train Acc: 0.8795, Test Acc: 0.8487
# ✓ Best model saved with Accuracy: 0.8487
# ____________________________________________________________
# Trail 1 - Epoch [100/210]
#   Train Acc: 0.8799, Test Acc: 0.8489
# ✓ Best model saved with Accuracy: 0.8489
# ____________________________________________________________
# Trail 1 - Epoch [101/210]
#   Train Acc: 0.8802, Test Acc: 0.8494
# ✓ Best model saved with Accuracy: 0.8494
# ____________________________________________________________
# Trail 1 - Epoch [102/210]
#   Train Acc: 0.8806, Test Acc: 0.8493
# Trail 1 - Epoch [103/210]
#   Train Acc: 0.8811, Test Acc: 0.8498
# ✓ Best model saved with Accuracy: 0.8498
# ____________________________________________________________
# Trail 1 - Epoch [104/210]
#   Train Acc: 0.8815, Test Acc: 0.8502
# ✓ Best model saved with Accuracy: 0.8502
# ____________________________________________________________
# Trail 1 - Epoch [105/210]
#   Train Acc: 0.8817, Test Acc: 0.8498
# Trail 1 - Epoch [106/210]
#   Train Acc: 0.8824, Test Acc: 0.8505
# ✓ Best model saved with Accuracy: 0.8505
# ____________________________________________________________
# Trail 1 - Epoch [107/210]
#   Train Acc: 0.8826, Test Acc: 0.8505
# ✓ Best model saved with Accuracy: 0.8505
# ____________________________________________________________
# Trail 1 - Epoch [108/210]
#   Train Acc: 0.8832, Test Acc: 0.8505
# ✓ Best model saved with Accuracy: 0.8505
# ____________________________________________________________
# Trail 1 - Epoch [109/210]
#   Train Acc: 0.8833, Test Acc: 0.8504
# Trail 1 - Epoch [110/210]
#   Train Acc: 0.8836, Test Acc: 0.8506
# ✓ Best model saved with Accuracy: 0.8506
# ____________________________________________________________
# Trail 1 - Epoch [111/210]
#   Train Acc: 0.8839, Test Acc: 0.8508
# ✓ Best model saved with Accuracy: 0.8508
# ____________________________________________________________
# Trail 1 - Epoch [112/210]
#   Train Acc: 0.8845, Test Acc: 0.8509
# ✓ Best model saved with Accuracy: 0.8509
# ____________________________________________________________
# Trail 1 - Epoch [113/210]
#   Train Acc: 0.8846, Test Acc: 0.8513
# ✓ Best model saved with Accuracy: 0.8513
# ____________________________________________________________
# Trail 1 - Epoch [114/210]
#   Train Acc: 0.8851, Test Acc: 0.8516
# ✓ Best model saved with Accuracy: 0.8516
# ____________________________________________________________
# Trail 1 - Epoch [115/210]
#   Train Acc: 0.8855, Test Acc: 0.8512
# Trail 1 - Epoch [116/210]
#   Train Acc: 0.8857, Test Acc: 0.8513
# Trail 1 - Epoch [117/210]
#   Train Acc: 0.8862, Test Acc: 0.8517
# ✓ Best model saved with Accuracy: 0.8517
# ____________________________________________________________
# Trail 1 - Epoch [118/210]
#   Train Acc: 0.8866, Test Acc: 0.8517
# ✓ Best model saved with Accuracy: 0.8517
# ____________________________________________________________
# Trail 1 - Epoch [119/210]
#   Train Acc: 0.8867, Test Acc: 0.8521
# ✓ Best model saved with Accuracy: 0.8521
# ____________________________________________________________
# Trail 1 - Epoch [120/210]
#   Train Acc: 0.8872, Test Acc: 0.8522
# ✓ Best model saved with Accuracy: 0.8522
# ____________________________________________________________
# Trail 1 - Epoch [121/210]
#   Train Acc: 0.8876, Test Acc: 0.8522
# ✓ Best model saved with Accuracy: 0.8522
# ____________________________________________________________
# Trail 1 - Epoch [122/210]
#   Train Acc: 0.8875, Test Acc: 0.8523
# ✓ Best model saved with Accuracy: 0.8523
# ____________________________________________________________
# Trail 1 - Epoch [123/210]
#   Train Acc: 0.8879, Test Acc: 0.8526
# ✓ Best model saved with Accuracy: 0.8526
# ____________________________________________________________
# Trail 1 - Epoch [124/210]
#   Train Acc: 0.8883, Test Acc: 0.8525
# Trail 1 - Epoch [125/210]
#   Train Acc: 0.8886, Test Acc: 0.8529
# ✓ Best model saved with Accuracy: 0.8529
# ____________________________________________________________
# Trail 1 - Epoch [126/210]
#   Train Acc: 0.8890, Test Acc: 0.8533
# ✓ Best model saved with Accuracy: 0.8533
# ____________________________________________________________
# Trail 1 - Epoch [127/210]
#   Train Acc: 0.8889, Test Acc: 0.8530
# Trail 1 - Epoch [128/210]
#   Train Acc: 0.8895, Test Acc: 0.8537
# ✓ Best model saved with Accuracy: 0.8537
# ____________________________________________________________
# Trail 1 - Epoch [129/210]
#   Train Acc: 0.8899, Test Acc: 0.8538
# ✓ Best model saved with Accuracy: 0.8538
# ____________________________________________________________
# Trail 1 - Epoch [130/210]
#   Train Acc: 0.8900, Test Acc: 0.8539
# ✓ Best model saved with Accuracy: 0.8539
# ____________________________________________________________
# Trail 1 - Epoch [131/210]
#   Train Acc: 0.8907, Test Acc: 0.8539
# ✓ Best model saved with Accuracy: 0.8539
# ____________________________________________________________
# Trail 1 - Epoch [132/210]
#   Train Acc: 0.8906, Test Acc: 0.8539
# Trail 1 - Epoch [133/210]
#   Train Acc: 0.8908, Test Acc: 0.8541
# ✓ Best model saved with Accuracy: 0.8541
# ____________________________________________________________
# Trail 1 - Epoch [134/210]
#   Train Acc: 0.8914, Test Acc: 0.8542
# ✓ Best model saved with Accuracy: 0.8542
# ____________________________________________________________
# Trail 1 - Epoch [135/210]
#   Train Acc: 0.8918, Test Acc: 0.8543
# ✓ Best model saved with Accuracy: 0.8543
# ____________________________________________________________
# Trail 1 - Epoch [136/210]
#   Train Acc: 0.8919, Test Acc: 0.8546
# ✓ Best model saved with Accuracy: 0.8546
# ____________________________________________________________
# Trail 1 - Epoch [137/210]
#   Train Acc: 0.8923, Test Acc: 0.8546
# Trail 1 - Epoch [138/210]
#   Train Acc: 0.8923, Test Acc: 0.8549
# ✓ Best model saved with Accuracy: 0.8549
# ____________________________________________________________
# Trail 1 - Epoch [139/210]
#   Train Acc: 0.8926, Test Acc: 0.8549
# ✓ Best model saved with Accuracy: 0.8549
# ____________________________________________________________
# Trail 1 - Epoch [140/210]
#   Train Acc: 0.8928, Test Acc: 0.8552
# ✓ Best model saved with Accuracy: 0.8552
# ____________________________________________________________
# Trail 1 - Epoch [141/210]
#   Train Acc: 0.8931, Test Acc: 0.8553
# ✓ Best model saved with Accuracy: 0.8553
# ____________________________________________________________
# Trail 1 - Epoch [142/210]
#   Train Acc: 0.8933, Test Acc: 0.8555
# ✓ Best model saved with Accuracy: 0.8555
# ____________________________________________________________
# Trail 1 - Epoch [143/210]
#   Train Acc: 0.8935, Test Acc: 0.8553
# Trail 1 - Epoch [144/210]
#   Train Acc: 0.8938, Test Acc: 0.8559
# ✓ Best model saved with Accuracy: 0.8559
# ____________________________________________________________
# Trail 1 - Epoch [145/210]
#   Train Acc: 0.8941, Test Acc: 0.8560
# ✓ Best model saved with Accuracy: 0.8560
# ____________________________________________________________
# Trail 1 - Epoch [146/210]
#   Train Acc: 0.8940, Test Acc: 0.8561
# ✓ Best model saved with Accuracy: 0.8561
# ____________________________________________________________
# Trail 1 - Epoch [147/210]
#   Train Acc: 0.8945, Test Acc: 0.8563
# ✓ Best model saved with Accuracy: 0.8563
# ____________________________________________________________
# Trail 1 - Epoch [148/210]
#   Train Acc: 0.8946, Test Acc: 0.8565
# ✓ Best model saved with Accuracy: 0.8565
# ____________________________________________________________
# Trail 1 - Epoch [149/210]
#   Train Acc: 0.8949, Test Acc: 0.8560
# Trail 1 - Epoch [150/210]
#   Train Acc: 0.8950, Test Acc: 0.8564
# Trail 1 - Epoch [151/210]
#   Train Acc: 0.8951, Test Acc: 0.8565
# Early stopping after 151 epochs with best Accuracy: 0.8565
# ____________________________________________________________

# %%
torch.save(model, 'test.pth')

# %%
model = torch.load("test.pth", weights_only=False)

# %%
device = 'cuda'
class Spike_Detection_MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size, n_channels, time_window):
        super(Spike_Detection_MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, 16)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(16, output_size)
        self.sigmoid = nn.Sigmoid()  

        self.n_channels = n_channels
        self.time_window = time_window
    def forward(self, x):
        x = x.reshape(-1, self.n_channels * self.time_window)
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.sigmoid(x)
        return x
        
detection_model = torch.load(f'/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_detection/train_results/trail_1.pth', weights_only=False)
detection_model.eval()

# %% [markdown]
# ## Month 2 Eval

# %%
import pickle
with open("/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_results/021322/neuron_inf.pkl", 'rb') as f:
    neuron_inf = pickle.load(f)

# %%
def get_custom_color_list(labels):
    """完全自定义颜色列表"""
    # 这里可以定义你喜欢的颜色组合
    my_colors = ["#e24182", "#ab415f", "#914d5a", "#dd8182",
                 "#ca4b54", "#e03445", "#d84624", "#a14c32",
                 "#e57f5e", "#cd6822", "#9c6b39", "#e89c35",
                 "#dba96e", "#b08025", "#70672a", "#bfb53b", "#7f7e1d",
                 "#99974c", "#8dbd36", "#9eb96f", "#52712a",
                 "#4d912e", "#50c147", "#438d50", "#56c47f",
                 "#297250", "#5ab18f", "#43c4c6", "#4c9ad1",
                 "#8690dc", "#6564db", "#645aa5", "#9f4dcf",
                 "#ca86d6", "#965388", "#dd4ac1", "#b4418f",
                 "#e084ac"]
    
    unique_labels = np.unique(labels)
    n_labels = len(unique_labels)
    
    
    color_map = {label: color for label, color in zip(unique_labels, my_colors)}
    return color_map

# %%
color_map = get_custom_color_list(neuron_inf['Neuron'].values)

# %%
#for date in ['012123', '022223', '022522', '031722', '032123', '042323', '042422', '052422', '062422', '072322', '082322']:
for date in ['102122', '122022']:
    print(f"Processing {date}...")
    spike_inf_aligned = pd.read_csv(
        f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/kilosort_spike_sorting/sorting_results/{date}/spike_inf_with_alignment.csv",
        index_col=0,
        )

    recording_raw = se.read_blackrock(file_path=f'/media/ubuntu/sda/data/mouse6/ns4/natural_image/mouse6_{date}_natural_image_001.ns4')
    recording_recorded = recording_raw.remove_channels(['98', '31', '32'])

    recording_f_22522 = spre.bandpass_filter(recording_recorded, freq_min=300, freq_max=3000)
    recording_f_22522 = spre.common_reference(recording_f_22522, reference="global", operator="median")

    calibration_duration = 60  # 秒
    sampling_rate = 10000
    calibration_frames = calibration_duration * sampling_rate  # 600000

    # 提取前60秒的数据
    calibration_data = recording_f_22522.get_traces(
        start_frame=0,
        end_frame=calibration_frames
    ).T

    print(f"校准数据形状: {calibration_data.shape}")

    # 检测峰值
    threshold_result = detect_local_minimum_in_window(
                calibration_data,
                std_multiplier=3.5,
                window_size= 30
            )

    calibration_threshold_result = np.array(threshold_result)

    half_window = 15
    valid_calibration_indices = calibration_threshold_result[
        (calibration_threshold_result >= half_window + 1) & 
        (calibration_threshold_result < calibration_frames - half_window)
    ]

    # 提取窗口
    calibration_windows = extract_windows(
        calibration_data,
        valid_calibration_indices,
        window_size=31
    )

    print(f"提取的spike数量: {len(calibration_windows)}")


    model.eval()
    device = 'cuda'
    calibration_embeddings = []

    print(f"提取的候选spike数量: {len(calibration_windows)}")

    if len(calibration_windows) == 0:
        raise RuntimeError("未在前60秒内检测到候选事件")

    # 使用spike detection模型筛选真正的spike
    detection_keep_mask = []
    with torch.no_grad():
        batch_size = 2048
        for i in range(0, len(calibration_windows), batch_size):
            batch = calibration_windows[i:i + batch_size]
            batch_tensor = torch.FloatTensor(batch).to(device)
            outputs = detection_model(batch_tensor).squeeze(-1)
            detection_keep_mask.append((outputs > 0.5).cpu().numpy())

    detection_keep_mask = np.concatenate(detection_keep_mask)
    calibration_windows = calibration_windows[detection_keep_mask]
    valid_calibration_indices = valid_calibration_indices[detection_keep_mask]

    print(f"通过检测模型筛选后的spike数量: {len(calibration_windows)}")

    if len(calibration_windows) == 0:
        raise RuntimeError("检测模型未在前60秒内识别到spike，请检查阈值或模型权重。")

    with torch.no_grad():
        # 批处理提取特征
        batch_size = 1024
        for i in range(0, len(calibration_windows), batch_size):
            batch = calibration_windows[i:i+batch_size]
            batch_tensor = torch.FloatTensor(batch).to(device)
            # 使用eval模式获取特征
            features = model(batch_tensor, mode='eval')
            calibration_embeddings.append(features.cpu().numpy())

    calibration_embeddings = np.vstack(calibration_embeddings)
    print(f"Latent embeddings形状: {calibration_embeddings.shape}")
    # 使用KMeans聚类
    # 聚类数量设置为neuron_inf中的神经元数量加一些余量（考虑可能出现的新神经元）
    n_clusters = len(neuron_inf)  

    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    calibration_clusters = kmeans.fit_predict(calibration_embeddings)

    print(f"聚类数量: {n_clusters}")
    print(f"各cluster的spike数量: {np.bincount(calibration_clusters)}")
    # 创建校准期间的spike信息DataFrame
    calibration_spike_inf = pd.DataFrame({
        'time': valid_calibration_indices,
        'cluster_predicted': calibration_clusters
    })

    # 计算每个cluster的平均waveform
    cluster_waveforms = compute_cluster_average(
        calibration_windows,
        calibration_spike_inf,
        cluster_column='cluster_predicted'
    )

    # 处理cluster_waveforms，找到最大值所在的通道，并保留对应的6个通道
    processed_cluster_waveforms = process_cluster_averages(
        cluster_waveforms,
        channel_indices
    )

    print(f"处理后的cluster数量: {len(processed_cluster_waveforms)}")


    # 为每个cluster计算位置和position_waveform
    cluster_info_list = []

    for cluster_key, waveform in processed_cluster_waveforms.items():
        cluster_id, probe_group = cluster_key.split('_')
        cluster_id = int(cluster_id)
        
        # 计算位置
        channels = channel_indices[probe_group]
        a_squared = [np.sum(waveform[j, :]**2) for j in range(len(channels))]
        
        sum_x_a = 0
        sum_y_a = 0
        sum_a = 0
        
        for j, channel in enumerate(channels):
            x_i, y_i = channel_position.get(channel, [0, 0])
            a_i_sq = a_squared[j]
            sum_x_a += x_i * a_i_sq
            sum_y_a += y_i * a_i_sq
            sum_a += a_i_sq
        
        if sum_a == 0:
            continue
        
        x_hat = sum_x_a / sum_a
        y_hat = sum_y_a / sum_a
        
        # 计算position_waveform
        distances = []
        for channel in channels:
            x_channel, y_channel = channel_position.get(channel, [np.nan, np.nan])
            if not np.isnan(x_channel):
                distance = np.sqrt((x_hat - x_channel)**2 + (y_hat - y_channel)**2)
                distances.append(distance)
        
        if not distances:
            continue
        
        # IDW插值
        weights = 1 / (np.array(distances) ** 2)
        if np.any(np.array(distances) == 0):
            zero_idx = np.argwhere(np.array(distances) == 0).flatten()
            position_waveform = waveform[zero_idx[0], :]
        else:
            weights /= np.sum(weights)
            position_waveform = np.zeros(31)
            for t in range(31):
                position_waveform[t] = np.dot(waveform[:, t], weights)
        
        cluster_info_list.append({
            'cluster_predicted': cluster_id,
            'probe_group': int(probe_group),
            'position_1': x_hat,
            'position_2': y_hat,
            'position_waveform': position_waveform,
            'waveform': waveform
        })

    cluster_info_df = pd.DataFrame(cluster_info_list)
    print(f"生成的cluster信息数量: {len(cluster_info_df)}")


    from scipy.stats import pearsonr

    cluster_to_neuron_mapping = {}
    position_threshold = 10
    waveform_threshold = 0.95

    for idx, cluster_row in cluster_info_df.iterrows():
        # 根据位置筛选候选神经元
        position_condition = (
            (abs(neuron_inf['position_1'] - cluster_row['position_1']) <= position_threshold) &
            (abs(neuron_inf['position_2'] - cluster_row['position_2']) <= position_threshold)
        )
        
        candidate_neurons = neuron_inf[position_condition]
        
        if candidate_neurons.empty:
            # 没有匹配的神经元，可能是新出现的神经元
            cluster_to_neuron_mapping[cluster_row['cluster_predicted']] = None
            continue
        
        # 使用波形相关性找到最佳匹配
        cluster_waveform = cluster_row['position_waveform']  # 31个点
        best_match = None
        best_corr = -1
        
        for _, neuron_row in candidate_neurons.iterrows():
            neuron_waveform = neuron_row['position_waveform']  # 可能是61个点
            
            # 处理长度不一致的问题
            if len(neuron_waveform) == 61 and len(cluster_waveform) == 31:
                # neuron_waveform取中间31个点
                neuron_waveform_aligned = neuron_waveform[15:46]
            elif len(neuron_waveform) == 31 and len(cluster_waveform) == 31:
                neuron_waveform_aligned = neuron_waveform
            else:
                # 其他情况，取最小长度
                min_len = min(len(neuron_waveform), len(cluster_waveform))
                neuron_waveform_aligned = neuron_waveform[:min_len]
                cluster_waveform = cluster_waveform[:min_len]
            
            # 计算Pearson相关系数
            corr, _ = pearsonr(cluster_waveform, neuron_waveform_aligned)
            
            if corr > waveform_threshold and corr > best_corr:
                best_corr = corr
                # 使用Neuron列而不是cluster列
                best_match = neuron_row['Neuron']
        
        cluster_to_neuron_mapping[cluster_row['cluster_predicted']] = best_match

    # 输出映射关系
    print("Cluster到Neuron的映射关系:")
    print("=" * 60)
    matched_count = sum(1 for v in cluster_to_neuron_mapping.values() if v is not None)
    unmatched_count = sum(1 for v in cluster_to_neuron_mapping.values() if v is None)
    print(f"成功匹配的cluster: {matched_count}")
    print(f"未匹配的cluster（可能是新神经元或噪音）: {unmatched_count}")
    print("=" * 60)

    # 处理完整数据集（包括校准期和后续时间）
    total_frames = int(recording_f_22522.get_total_duration() * 10000)
    chunk_size = 100000
    window_size = 31
    half_window = window_size // 2

    all_valid_indices = []
    all_windows = []
    all_embeddings = []
    all_clusters = []

    print("开始处理完整数据...")
    for start_frame in tqdm(range(0, total_frames, chunk_size)):
        end_frame = min(start_frame + chunk_size, total_frames)
        
        # 读取数据块
        data_chunk = recording_f_22522.get_traces(
            start_frame=start_frame,
            end_frame=end_frame
        ).T
        
        # 检测峰值
        threshold_result = detect_local_minimum_in_window(
            data_chunk,
            std_multiplier=3.5,
            window_size= 30
        )
        
        threshold_result = np.array(threshold_result) + start_frame
        valid_indices = threshold_result[
            (threshold_result >= start_frame + half_window + 1) & 
            (threshold_result < end_frame - half_window)
        ]
        
        if len(valid_indices) == 0:
            continue
        
        # 提取窗口
        for idx in valid_indices:
            rel_idx = idx - start_frame
            window = data_chunk[:, rel_idx-half_window : rel_idx+half_window+1]
            all_windows.append(window)
        
        all_valid_indices.extend(valid_indices)

    all_valid_indices = np.array(all_valid_indices)
    all_windows = np.stack(all_windows)

    print(f"总共检测到的候选事件数量: {len(all_windows)}")

    # 使用检测模型筛选真正的spike
    if len(all_windows) == 0:
        raise RuntimeError("在完整数据中未检测到任何候选事件。")

    full_detection_mask_list = []
    with torch.no_grad():
        batch_size = 4096
        for i in tqdm(range(0, len(all_windows), batch_size), desc="Detection filtering"):
            batch = all_windows[i:i + batch_size]
            batch_tensor = torch.FloatTensor(batch).to(device)
            outputs = detection_model(batch_tensor).squeeze(-1)
            full_detection_mask_list.append((outputs > 0.5).cpu().numpy())

    full_detection_mask = np.concatenate(full_detection_mask_list)

    all_windows = all_windows[full_detection_mask]
    all_valid_indices = all_valid_indices[full_detection_mask]

    print(f"通过检测模型筛选后的spike数量: {len(all_windows)}")

    if len(all_windows) == 0:
        raise RuntimeError("检测模型未在全数据中识别到spike，请检查阈值或模型。")

    # 提取所有数据的latent embedding并使用kmeans进行聚类
    model.eval()
    all_embeddings = []

    print("提取latent embeddings...")
    with torch.no_grad():
        batch_size = 1024
        for i in tqdm(range(0, len(all_windows), batch_size)):
            batch = all_windows[i:i+batch_size]
            batch_tensor = torch.FloatTensor(batch).to(device)
            features = model(batch_tensor, mode='eval')
            all_embeddings.append(features.cpu().numpy())

    all_embeddings = np.vstack(all_embeddings)
    print(f"所有embeddings形状: {all_embeddings.shape}")

    # 使用之前训练好的kmeans模型进行预测
    print("使用kmeans进行聚类...")
    all_clusters = predict_new(all_embeddings, kmeans)
    print(f"聚类完成，类别数: {len(np.unique(all_clusters))}")


    # 应用映射关系，将cluster_predicted转换为neuron_id
    final_neuron_ids = []

    for cluster_id in all_clusters:
        neuron_id = cluster_to_neuron_mapping.get(cluster_id, None)
        final_neuron_ids.append(neuron_id)

    final_neuron_ids = np.array(final_neuron_ids)

    # 创建最终的spike信息DataFrame
    final_spike_inf = pd.DataFrame({
        'time': all_valid_indices,
        'cluster_predicted': all_clusters,
        'neuron_id': final_neuron_ids
    })


    print("\n为final_spike_inf添加true_neuron列（完全向量化）...")

    # 准备数据
    aligned_times = spike_inf_aligned['time'].values
    aligned_neurons = spike_inf_aligned['Neuron'].values
    final_times = final_spike_inf['time'].values

    if not np.all(aligned_times[:-1] <= aligned_times[1:]):
        print("对aligned_times进行排序...")
        sort_idx = np.argsort(aligned_times)
        aligned_times = aligned_times[sort_idx]
        aligned_neurons = aligned_neurons[sort_idx]

    threshold = 5  # 时间误差阈值
    print(f"处理 {len(final_times)} 个spikes...")

    insert_positions = np.searchsorted(aligned_times, final_times)

    true_neurons = np.full(len(final_times), 'Invalid', dtype=object)
    matched_mask = np.zeros(len(final_times), dtype=bool)

    left_indices = insert_positions - 1
    valid_left = (left_indices >= 0)

    if np.any(valid_left):
        left_times = aligned_times[left_indices[valid_left]]
        left_diffs = np.abs(final_times[valid_left] - left_times)
        left_match = left_diffs <= threshold
        
        valid_left_indices = np.where(valid_left)[0]
        matched_left_indices = valid_left_indices[left_match]
        true_neurons[matched_left_indices] = aligned_neurons[left_indices[matched_left_indices]]
        matched_mask[matched_left_indices] = True

    right_indices = insert_positions
    valid_right = (right_indices < len(aligned_times))

    if np.any(valid_right):
        right_times = aligned_times[right_indices[valid_right]]
        right_diffs = np.abs(final_times[valid_right] - right_times)
        right_match = right_diffs <= threshold
        
        valid_right_indices = np.where(valid_right)[0]
        matched_right_indices = valid_right_indices[right_match]
        
        for idx in matched_right_indices:
            if not matched_mask[idx]:
                true_neurons[idx] = aligned_neurons[right_indices[idx]]
                matched_mask[idx] = True
            else:
                # 左右都匹配，选择距离更近的
                left_diff = abs(final_times[idx] - aligned_times[left_indices[idx]])
                right_diff = abs(final_times[idx] - aligned_times[right_indices[idx]])
                if right_diff < left_diff:
                    true_neurons[idx] = aligned_neurons[right_indices[idx]]

    final_spike_inf['true_neuron'] = true_neurons

    import umap
    valid_spike_inf = final_spike_inf[final_spike_inf['neuron_id'].notnull()]
    valid_spike_inf = valid_spike_inf[valid_spike_inf['true_neuron'] != 'Invalid']
    valid_spike_inf = valid_spike_inf[valid_spike_inf['true_neuron'].notna()]
    all_embeddings_plot = all_embeddings[valid_spike_inf.index, :]

    random_sample = random.sample(range(len(all_embeddings_plot)), 20000)
    umap_model = umap.UMAP(n_components=2, random_state=42)
    embeddings_2d = umap_model.fit_transform(all_embeddings_plot[random_sample, :])

    valid_spike_inf.index = range(len(valid_spike_inf))
    with PdfPages(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_classification/evale_results/spike_classification_umap_{date}.pdf") as pdf:
        true_labels_in_plot = np.unique(valid_spike_inf.loc[np.array(random_sample), 'true_neuron'].values)
        pred_labels_in_plot = np.unique(valid_spike_inf.loc[np.array(random_sample), 'neuron_id'].values)
        
        # 从完整颜色映射中提取实际出现的标签对应的颜色
        true_color_subset = {label: color_map[label] for label in true_labels_in_plot}
        pred_color_subset = {label: color_map[label] for label in pred_labels_in_plot}
        
        # 第一个图：真实标签
        plt.figure(figsize=(8, 8))
        sns.scatterplot(
                x=embeddings_2d[:, 0], 
                y=embeddings_2d[:, 1], 
                hue=valid_spike_inf.loc[np.array(random_sample), 'true_neuron'].values, 
                palette=true_color_subset,  # 使用实际出现的标签对应的颜色
                alpha=1, 
                s=2, 
                legend=False, 
                linewidth=0
        )
        plt.title(f"UMAP Visualization - True Labels")
        plt.grid(False)
        plt.xticks([])
        plt.yticks([])
        pdf.savefig()  
        plt.close()

        # 第二个图：预测标签
        plt.figure(figsize=(8, 8))
        sns.scatterplot(
                x=embeddings_2d[:, 0], 
                y=embeddings_2d[:, 1], 
                hue=valid_spike_inf.loc[np.array(random_sample), 'neuron_id'].values, 
                palette=pred_color_subset,  # 使用实际出现的标签对应的颜色
                alpha=1, 
                s=2, 
                legend=False, 
                linewidth=0
        )
        plt.title(f"UMAP Visualization - Predicted Labels")
        plt.grid(False)
        plt.xticks([])
        plt.yticks([])
        pdf.savefig()  
        plt.close()

    cross = pd.crosstab(valid_spike_inf['neuron_id'], valid_spike_inf['true_neuron'])
    from sklearn.preprocessing import MinMaxScaler

    scaler = MinMaxScaler()
    cross_normalized = pd.DataFrame(
        scaler.fit_transform(cross),
        index=cross.index,
        columns=cross.columns
    )

    with PdfPages(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_classification/evale_results/spike_classification_heatmap_{date}.pdf") as pdf:
        sns.heatmap(cross_normalized, cmap = 'Blues')
        pdf.savefig()
        plt.close()

    cross.to_csv(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_classification/evale_results/spike_classification_heatmap_{date}.csv")
    cross.to_csv(f"/media/ubuntu/sda/Spike_Sorting/paper_architecture/01_real_data/01_flexible_probe_30_channels/spike_classification/evale_results/spike_classification_heatmap_{date}.csv")
# Out:
# Processing 102122...
# 校准数据形状: (30, 600000)
# 提取的spike数量: 44710
# 提取的候选spike数量: 44710
# 通过检测模型筛选后的spike数量: 26524
# Latent embeddings形状: (26524, 50)
# 聚类数量: 38
# 各cluster的spike数量: [ 378 1071 1235  782  659  559  385  275  910 1003  911  932  527  728
#   972  420  325  596  712  809 1237  729  745  904  655 1133  857  520
#   365  733  364  853 1111  519  358  531  294  427]
# 处理后的cluster数量: 38
# 生成的cluster信息数量: 38
# Cluster到Neuron的映射关系:
# ============================================================
# 成功匹配的cluster: 27
# 未匹配的cluster（可能是新神经元或噪音）: 11
# ============================================================
# 开始处理完整数据...
# 100%|██████████| 241/241 [17:43<00:00,  4.41s/it]
# 总共检测到的候选事件数量: 1701526
# Detection filtering: 100%|██████████| 416/416 [00:00<00:00, 419.03it/s]
# 通过检测模型筛选后的spike数量: 964711
# 提取latent embeddings...
# 100%|██████████| 943/943 [00:00<00:00, 1060.47it/s]
# 所有embeddings形状: (964711, 50)
# 使用kmeans进行聚类...
# 聚类完成，类别数: 38
#
# 为final_spike_inf添加true_neuron列（完全向量化）...
# 处理 964711 个spikes...
# Processing 122022...
# 校准数据形状: (30, 600000)
# 提取的spike数量: 42203
# 提取的候选spike数量: 42203
# 通过检测模型筛选后的spike数量: 24128
# Latent embeddings形状: (24128, 50)
# 聚类数量: 38
# 各cluster的spike数量: [ 721  332  724  418  947  918  710  816  970  379  515  829  916  377
#   793  406  442  606 1175  638  765  951  256  576  238  780  529  777
#   339  672  824  355  406  543  479  708  887  411]
# 处理后的cluster数量: 38
# 生成的cluster信息数量: 38
# Cluster到Neuron的映射关系:
# ============================================================
# 成功匹配的cluster: 26
# 未匹配的cluster（可能是新神经元或噪音）: 12
# ============================================================
# 开始处理完整数据...
# 100%|██████████| 254/254 [11:19<00:00,  2.68s/it]
# 总共检测到的候选事件数量: 1752913
# Detection filtering: 100%|██████████| 428/428 [00:05<00:00, 71.92it/s]
# 通过检测模型筛选后的spike数量: 934488
# 提取latent embeddings...
# 100%|██████████| 913/913 [00:10<00:00, 84.97it/s]
# 所有embeddings形状: (934488, 50)
# 使用kmeans进行聚类...
# 聚类完成，类别数: 38
#
# 为final_spike_inf添加true_neuron列（完全向量化）...
# 处理 934488 个spikes...

# %%
model.eval()
device = 'cuda'
calibration_embeddings = []

print(f"提取的候选spike数量: {len(calibration_windows)}")

if len(calibration_windows) == 0:
    raise RuntimeError("未在前60秒内检测到候选事件")

# 使用spike detection模型筛选真正的spike
detection_keep_mask = []
with torch.no_grad():
    batch_size = 2048
    for i in range(0, len(calibration_windows), batch_size):
        batch = calibration_windows[i:i + batch_size]
        batch_tensor = torch.FloatTensor(batch).to(device)
        outputs = detection_model(batch_tensor).squeeze(-1)
        detection_keep_mask.append((outputs > 0.5).cpu().numpy())

detection_keep_mask = np.concatenate(detection_keep_mask)
calibration_windows = calibration_windows[detection_keep_mask]
valid_calibration_indices = valid_calibration_indices[detection_keep_mask]

print(f"通过检测模型筛选后的spike数量: {len(calibration_windows)}")

if len(calibration_windows) == 0:
    raise RuntimeError("检测模型未在前60秒内识别到spike，请检查阈值或模型权重。")

with torch.no_grad():
    # 批处理提取特征
    batch_size = 1024
    for i in range(0, len(calibration_windows), batch_size):
        batch = calibration_windows[i:i+batch_size]
        batch_tensor = torch.FloatTensor(batch).to(device)
        # 使用eval模式获取特征
        features = model(batch_tensor, mode='eval')
        calibration_embeddings.append(features.cpu().numpy())

calibration_embeddings = np.vstack(calibration_embeddings)
print(f"Latent embeddings形状: {calibration_embeddings.shape}")
# 使用KMeans聚类
# 聚类数量设置为neuron_inf中的神经元数量加一些余量（考虑可能出现的新神经元）
n_clusters = len(neuron_inf)  

kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
calibration_clusters = kmeans.fit_predict(calibration_embeddings)

print(f"聚类数量: {n_clusters}")
print(f"各cluster的spike数量: {np.bincount(calibration_clusters)}")
# 创建校准期间的spike信息DataFrame
calibration_spike_inf = pd.DataFrame({
    'time': valid_calibration_indices,
    'cluster_predicted': calibration_clusters
})

# 计算每个cluster的平均waveform
cluster_waveforms = compute_cluster_average(
    calibration_windows,
    calibration_spike_inf,
    cluster_column='cluster_predicted'
)

# 处理cluster_waveforms，找到最大值所在的通道，并保留对应的6个通道
processed_cluster_waveforms = process_cluster_averages(
    cluster_waveforms,
    channel_indices
)

print(f"处理后的cluster数量: {len(processed_cluster_waveforms)}")
# Out:
# 提取的候选spike数量: 46485
# 通过检测模型筛选后的spike数量: 26935
# Latent embeddings形状: (26935, 50)
# 聚类数量: 38
# 各cluster的spike数量: [ 393  981  572  646  317  792  842  448  266  927  541  577  342  304
#   890 1117  767 1091  667 1059  981 1370  527  464  778  681  990  891
#   768 1026  363  343  454  469  876  743  956  716]
# 处理后的cluster数量: 38

# %%
# 为每个cluster计算位置和position_waveform
cluster_info_list = []

for cluster_key, waveform in processed_cluster_waveforms.items():
    cluster_id, probe_group = cluster_key.split('_')
    cluster_id = int(cluster_id)
    
    # 计算位置
    channels = channel_indices[probe_group]
    a_squared = [np.sum(waveform[j, :]**2) for j in range(len(channels))]
    
    sum_x_a = 0
    sum_y_a = 0
    sum_a = 0
    
    for j, channel in enumerate(channels):
        x_i, y_i = channel_position.get(channel, [0, 0])
        a_i_sq = a_squared[j]
        sum_x_a += x_i * a_i_sq
        sum_y_a += y_i * a_i_sq
        sum_a += a_i_sq
    
    if sum_a == 0:
        continue
    
    x_hat = sum_x_a / sum_a
    y_hat = sum_y_a / sum_a
    
    # 计算position_waveform
    distances = []
    for channel in channels:
        x_channel, y_channel = channel_position.get(channel, [np.nan, np.nan])
        if not np.isnan(x_channel):
            distance = np.sqrt((x_hat - x_channel)**2 + (y_hat - y_channel)**2)
            distances.append(distance)
    
    if not distances:
        continue
    
    # IDW插值
    weights = 1 / (np.array(distances) ** 2)
    if np.any(np.array(distances) == 0):
        zero_idx = np.argwhere(np.array(distances) == 0).flatten()
        position_waveform = waveform[zero_idx[0], :]
    else:
        weights /= np.sum(weights)
        position_waveform = np.zeros(31)
        for t in range(31):
            position_waveform[t] = np.dot(waveform[:, t], weights)
    
    cluster_info_list.append({
        'cluster_predicted': cluster_id,
        'probe_group': int(probe_group),
        'position_1': x_hat,
        'position_2': y_hat,
        'position_waveform': position_waveform,
        'waveform': waveform
    })

cluster_info_df = pd.DataFrame(cluster_info_list)
print(f"生成的cluster信息数量: {len(cluster_info_df)}")
# Out:
# 生成的cluster信息数量: 38

# %%
# 建立映射关系：cluster_predicted -> Neuron
from scipy.stats import pearsonr

cluster_to_neuron_mapping = {}
position_threshold = 10
waveform_threshold = 0.95

for idx, cluster_row in cluster_info_df.iterrows():
    # 根据位置筛选候选神经元
    position_condition = (
        (abs(neuron_inf['position_1'] - cluster_row['position_1']) <= position_threshold) &
        (abs(neuron_inf['position_2'] - cluster_row['position_2']) <= position_threshold)
    )
    
    candidate_neurons = neuron_inf[position_condition]
    
    if candidate_neurons.empty:
        # 没有匹配的神经元，可能是新出现的神经元
        cluster_to_neuron_mapping[cluster_row['cluster_predicted']] = None
        continue
    
    # 使用波形相关性找到最佳匹配
    cluster_waveform = cluster_row['position_waveform']  # 31个点
    best_match = None
    best_corr = -1
    
    for _, neuron_row in candidate_neurons.iterrows():
        neuron_waveform = neuron_row['position_waveform']  # 可能是61个点
        
        # 处理长度不一致的问题
        if len(neuron_waveform) == 61 and len(cluster_waveform) == 31:
            # neuron_waveform取中间31个点
            neuron_waveform_aligned = neuron_waveform[15:46]
        elif len(neuron_waveform) == 31 and len(cluster_waveform) == 31:
            neuron_waveform_aligned = neuron_waveform
        else:
            # 其他情况，取最小长度
            min_len = min(len(neuron_waveform), len(cluster_waveform))
            neuron_waveform_aligned = neuron_waveform[:min_len]
            cluster_waveform = cluster_waveform[:min_len]
        
        # 计算Pearson相关系数
        corr, _ = pearsonr(cluster_waveform, neuron_waveform_aligned)
        
        if corr > waveform_threshold and corr > best_corr:
            best_corr = corr
            # 使用Neuron列而不是cluster列
            best_match = neuron_row['Neuron']
    
    cluster_to_neuron_mapping[cluster_row['cluster_predicted']] = best_match

# 输出映射关系
print("Cluster到Neuron的映射关系:")
print("=" * 60)
matched_count = sum(1 for v in cluster_to_neuron_mapping.values() if v is not None)
unmatched_count = sum(1 for v in cluster_to_neuron_mapping.values() if v is None)
print(f"成功匹配的cluster: {matched_count}")
print(f"未匹配的cluster（可能是新神经元或噪音）: {unmatched_count}")
print("=" * 60)
for cluster_id, neuron_id in sorted(cluster_to_neuron_mapping.items()):
    if neuron_id is not None:
        print(f"Cluster {cluster_id} -> {neuron_id}")
    else:
        print(f"Cluster {cluster_id} -> 未匹配（新神经元或噪音）")
# Out:
# Cluster到Neuron的映射关系:
# ============================================================
# 成功匹配的cluster: 29
# 未匹配的cluster（可能是新神经元或噪音）: 9
# ============================================================
# Cluster 0 -> 未匹配（新神经元或噪音）
# Cluster 1 -> Neuron_44
# Cluster 2 -> Neuron_20
# Cluster 3 -> Neuron_28
# Cluster 4 -> 未匹配（新神经元或噪音）
# Cluster 5 -> Neuron_42
# Cluster 6 -> Neuron_19
# Cluster 7 -> 未匹配（新神经元或噪音）
# Cluster 8 -> Neuron_31
# Cluster 9 -> Neuron_8
# Cluster 10 -> Neuron_33
# Cluster 11 -> Neuron_24
# Cluster 12 -> Neuron_42
# Cluster 13 -> Neuron_45
# Cluster 14 -> 未匹配（新神经元或噪音）
# Cluster 15 -> 未匹配（新神经元或噪音）
# Cluster 16 -> Neuron_18
# Cluster 17 -> Neuron_39
# Cluster 18 -> Neuron_30
# Cluster 19 -> Neuron_28
# Cluster 20 -> Neuron_42
# Cluster 21 -> Neuron_8
# Cluster 22 -> Neuron_42
# Cluster 23 -> 未匹配（新神经元或噪音）
# Cluster 24 -> Neuron_8
# Cluster 25 -> 未匹配（新神经元或噪音）
# Cluster 26 -> Neuron_12
# Cluster 27 -> Neuron_40
# Cluster 28 -> 未匹配（新神经元或噪音）
# Cluster 29 -> Neuron_2
# Cluster 30 -> Neuron_33
# Cluster 31 -> 未匹配（新神经元或噪音）
# Cluster 32 -> Neuron_36
# Cluster 33 -> Neuron_31
# Cluster 34 -> Neuron_20
# Cluster 35 -> Neuron_37
# Cluster 36 -> Neuron_42
# Cluster 37 -> Neuron_45

# %%
# 处理完整数据集（包括校准期和后续时间）
total_frames = int(recording_f_22522.get_total_duration() * 10000)
chunk_size = 100000
window_size = 31
half_window = window_size // 2

all_valid_indices = []
all_windows = []
all_embeddings = []
all_clusters = []

print("开始处理完整数据...")
for start_frame in tqdm(range(0, total_frames, chunk_size)):
    end_frame = min(start_frame + chunk_size, total_frames)
    
    # 读取数据块
    data_chunk = recording_f_22522.get_traces(
        start_frame=start_frame,
        end_frame=end_frame
    ).T
    
    # 检测峰值
    threshold_result = detect_local_minimum_in_window(
        data_chunk,
        std_multiplier=3.5,
        window_size= 30
    )
    
    threshold_result = np.array(threshold_result) + start_frame
    valid_indices = threshold_result[
        (threshold_result >= start_frame + half_window + 1) & 
        (threshold_result < end_frame - half_window)
    ]
    
    if len(valid_indices) == 0:
        continue
    
    # 提取窗口
    for idx in valid_indices:
        rel_idx = idx - start_frame
        window = data_chunk[:, rel_idx-half_window : rel_idx+half_window+1]
        all_windows.append(window)
    
    all_valid_indices.extend(valid_indices)

all_valid_indices = np.array(all_valid_indices)
all_windows = np.stack(all_windows)

print(f"总共检测到的候选事件数量: {len(all_windows)}")

# 使用检测模型筛选真正的spike
if len(all_windows) == 0:
    raise RuntimeError("在完整数据中未检测到任何候选事件。")

full_detection_mask_list = []
with torch.no_grad():
    batch_size = 4096
    for i in tqdm(range(0, len(all_windows), batch_size), desc="Detection filtering"):
        batch = all_windows[i:i + batch_size]
        batch_tensor = torch.FloatTensor(batch).to(device)
        outputs = detection_model(batch_tensor).squeeze(-1)
        full_detection_mask_list.append((outputs > 0.5).cpu().numpy())

full_detection_mask = np.concatenate(full_detection_mask_list)

all_windows = all_windows[full_detection_mask]
all_valid_indices = all_valid_indices[full_detection_mask]

print(f"通过检测模型筛选后的spike数量: {len(all_windows)}")

if len(all_windows) == 0:
    raise RuntimeError("检测模型未在全数据中识别到spike，请检查阈值或模型。")
# Out:
# 开始处理完整数据...
# 100%|██████████| 261/261 [00:35<00:00,  7.32it/s]
# 总共检测到的候选事件数量: 1969580
# Detection filtering: 100%|██████████| 481/481 [00:00<00:00, 842.32it/s]
# 通过检测模型筛选后的spike数量: 1103079

# %%
# 提取所有数据的latent embedding并使用kmeans进行聚类
model.eval()
all_embeddings = []

print("提取latent embeddings...")
with torch.no_grad():
    batch_size = 1024
    for i in tqdm(range(0, len(all_windows), batch_size)):
        batch = all_windows[i:i+batch_size]
        batch_tensor = torch.FloatTensor(batch).to(device)
        features = model(batch_tensor, mode='eval')
        all_embeddings.append(features.cpu().numpy())

all_embeddings = np.vstack(all_embeddings)
print(f"所有embeddings形状: {all_embeddings.shape}")

# 使用之前训练好的kmeans模型进行预测
print("使用kmeans进行聚类...")
all_clusters = predict_new(all_embeddings, kmeans)
print(f"聚类完成，类别数: {len(np.unique(all_clusters))}")


# 应用映射关系，将cluster_predicted转换为neuron_id
final_neuron_ids = []

for cluster_id in all_clusters:
    neuron_id = cluster_to_neuron_mapping.get(cluster_id, None)
    final_neuron_ids.append(neuron_id)

final_neuron_ids = np.array(final_neuron_ids)

# 创建最终的spike信息DataFrame
final_spike_inf = pd.DataFrame({
    'time': all_valid_indices,
    'cluster_predicted': all_clusters,
    'neuron_id': final_neuron_ids
})


print("\n为final_spike_inf添加true_neuron列（完全向量化）...")

# 准备数据
aligned_times = spike_inf_aligned['time'].values
aligned_neurons = spike_inf_aligned['Neuron'].values
final_times = final_spike_inf['time'].values

if not np.all(aligned_times[:-1] <= aligned_times[1:]):
    print("对aligned_times进行排序...")
    sort_idx = np.argsort(aligned_times)
    aligned_times = aligned_times[sort_idx]
    aligned_neurons = aligned_neurons[sort_idx]

threshold = 5  # 时间误差阈值
print(f"处理 {len(final_times)} 个spikes...")

insert_positions = np.searchsorted(aligned_times, final_times)

true_neurons = np.full(len(final_times), 'Invalid', dtype=object)
matched_mask = np.zeros(len(final_times), dtype=bool)

left_indices = insert_positions - 1
valid_left = (left_indices >= 0)

if np.any(valid_left):
    left_times = aligned_times[left_indices[valid_left]]
    left_diffs = np.abs(final_times[valid_left] - left_times)
    left_match = left_diffs <= threshold
    
    valid_left_indices = np.where(valid_left)[0]
    matched_left_indices = valid_left_indices[left_match]
    true_neurons[matched_left_indices] = aligned_neurons[left_indices[matched_left_indices]]
    matched_mask[matched_left_indices] = True

right_indices = insert_positions
valid_right = (right_indices < len(aligned_times))

if np.any(valid_right):
    right_times = aligned_times[right_indices[valid_right]]
    right_diffs = np.abs(final_times[valid_right] - right_times)
    right_match = right_diffs <= threshold
    
    valid_right_indices = np.where(valid_right)[0]
    matched_right_indices = valid_right_indices[right_match]
    
    for idx in matched_right_indices:
        if not matched_mask[idx]:
            true_neurons[idx] = aligned_neurons[right_indices[idx]]
            matched_mask[idx] = True
        else:
            # 左右都匹配，选择距离更近的
            left_diff = abs(final_times[idx] - aligned_times[left_indices[idx]])
            right_diff = abs(final_times[idx] - aligned_times[right_indices[idx]])
            if right_diff < left_diff:
                true_neurons[idx] = aligned_neurons[right_indices[idx]]

final_spike_inf['true_neuron'] = true_neurons
# Out:
# 提取latent embeddings...
# 100%|██████████| 1078/1078 [00:00<00:00, 2443.66it/s]
# 所有embeddings形状: (1103079, 50)
# 使用kmeans进行聚类...
# 聚类完成，类别数: 38
#
# 为final_spike_inf添加true_neuron列（完全向量化）...
# 处理 1103079 个spikes...

# %%
import umap
valid_spike_inf = final_spike_inf[final_spike_inf['neuron_id'].notnull()]
valid_spike_inf = valid_spike_inf[valid_spike_inf['true_neuron'] != 'Invalid']
valid_spike_inf = valid_spike_inf[valid_spike_inf['true_neuron'].notna()]
all_embeddings_plot = all_embeddings[valid_spike_inf.index, :]

random_sample = random.sample(range(len(all_embeddings_plot)), 100000)
umap_model = umap.UMAP(n_components=2, random_state=42)
embeddings_2d = umap_model.fit_transform(all_embeddings_plot[random_sample, :])

valid_spike_inf.index = range(len(valid_spike_inf))
with PdfPages("test.pdf") as pdf:
    plt.figure(figsize=(8, 8))
    sns.scatterplot(x = embeddings_2d[:, 0], y = embeddings_2d[:, 1], hue=valid_spike_inf.loc[np.array(random_sample), 'true_neuron'].values, alpha=1, s = 2, legend=False)
    plt.title(f"UMAP Visualization - True Labels")
    plt.grid(False)
    pdf.savefig()  
    plt.close()

    plt.figure(figsize=(8, 8))
    sns.scatterplot(x = embeddings_2d[:, 0], y = embeddings_2d[:, 1], hue=valid_spike_inf.loc[np.array(random_sample), 'neuron_id'].values, alpha=1, s = 2, legend=False)
    plt.title(f"UMAP Visualization - Predicted Labels")
    plt.grid(False)
    pdf.savefig()  
    plt.close()

# %%
valid_spike_inf.loc[np.array(random_sample), 'true_neuron']
# Out:
# 326844    Neuron_12
# 41330     Neuron_37
# 309603    Neuron_19
# 273975     Neuron_2
# 47985     Neuron_42
#             ...
# 154359    Neuron_28
# 429069     Neuron_2
# 429265    Neuron_45
# 217646    Neuron_20
# 184133    Neuron_40
# Name: true_neuron, Length: 10000, dtype: object
