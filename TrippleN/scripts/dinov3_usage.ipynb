# %%
import torch

# %%
dino_v3 = torch.hub.load("/media/ubuntu/sda/paper_code/dinov3-main/", 'dinov3_vits16', source = 'local', weights = '/media/ubuntu/sda/TrippleN/model/dinov3_vits16_pretrain_lvd1689m-08c60483.pth')
# Out:
# Downloading: "file:///media/ubuntu/sda/TrippleN/model/dinov3_vits16_pretrain_lvd1689m-08c60483.pth" to /home/ubuntu/.cache/torch/hub/checkpoints/dinov3_vits16_pretrain_lvd1689m-08c60483.pth
# 100%|██████████| 82.5M/82.5M [00:00<00:00, 197MB/s]
